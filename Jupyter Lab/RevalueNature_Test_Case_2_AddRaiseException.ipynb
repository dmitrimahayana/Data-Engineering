# %% [markdown]
# # Use Case 1 - Summary of All Flight

# %% [markdown]
# ## Initialization

# %%
import os, json
import pandas as pd
import pprint

# %% [markdown]
# ## Assumption

# %% [markdown]
# ##### 1. One file is 1 flight id hence there is no way multiple flight in single file
# ##### 2. All file in json format and located under specific folder
# ##### 3. Normally, I will use Spark to accelerate the computation, but i choose simply dataframe because i just want to make sure at least we can extract the data into proper json format
# ##### 4. Due to limited time of completing exercise, I put maximum number of file which is 10 json to read into dataframe. Some of file unable to get extracted due to data cleansing issue

# %% [markdown]
# ## Load Dataset

# %%
folder_path = 'C:\\Users\\dmitr\\Downloads\\scat20161015_20161021\\' # Assuming this where all json file will be stored
json_files = [pos_json for pos_json in os.listdir(folder_path) if pos_json.endswith('.json')]

# %% [markdown]
# ## Extract Data Function

# %%
def extract_data(file):
    if os.path.exists(file):
        # Opening JSON file
        f = open(file)
        # Load JSON into object
        data = json.load(f)
        # Close file
        f.close()
        
        # Extract Header Data
        id = data['id']
        unique_aircraft_type = data['fpl']['fpl_base'][0]['aircraft_type']
        unique_flight_rules = data['fpl']['fpl_base'][0]['flight_rules']
        #print("id: ", id, " unique_aircraft_type: ",unique_aircraft_type, " unique_aircraft_type: ", unique_flight_rules)

        #Extract Item Data
        df = pd.DataFrame(data['plots'])
        # df['plots_max_altitude'] = df['I062/380'].apply(lambda x: x['subitem7']['altitude'])
        # df['plots_max_baro_vert_rate'] = df['I062/380'].apply(lambda x: x['subitem13']['baro_vert_rate'])
        # df['plots_max_mach'] = df['I062/380'].apply(lambda x: x['subitem27']['mach'])
        # df['plots_max_measured_flight_level'] = df['I062/136'].apply(lambda x: x['measured_flight_level'])\
        
        df_final = pd.DataFrame()
        try:
            df['plots_max_altitude'] = df['I062/380'].apply(lambda x: x['subitem7']['altitude'] if isinstance(x, dict) and 'subitem7' in x and 'altitude' in x['subitem7'] else None)
            df['plots_max_baro_vert_rate'] = df['I062/380'].apply(lambda x: x['subitem13']['baro_vert_rate'] if isinstance(x, dict) and 'subitem13' in x and 'baro_vert_rate' in x['subitem13'] else None)
            df['plots_max_mach'] = df['I062/380'].apply(lambda x: x['subitem27']['mach'] if isinstance(x, dict) and 'subitem27' in x and 'mach' in x['subitem27'] else None)
            df['plots_max_measured_flight_level'] = df['I062/136'].apply(lambda x: x['measured_flight_level'] if isinstance(x, dict) and 'measured_flight_level' in x else None)
            df_final = df[['plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level']]
            # print(df_final.head(5))
        except Exception as e:
            for col in df.columns:
                if 'altitude' in df[col].values:
                    df['plots_max_altitude'] = df[col].apply(lambda x: x['subitem7']['altitude'] if isinstance(x, dict) and 'subitem7' in x and 'altitude' in x['subitem7'] else None)
                elif 'baro_vert_rate' in df[col].values:
                    df['plots_max_baro_vert_rate'] = df[col].apply(lambda x: x['subitem13']['baro_vert_rate'] if isinstance(x, dict) and 'subitem13' in x and 'baro_vert_rate' in x['subitem13'] else None)
                elif 'mach' in df[col].values:
                    df['plots_max_mach'] = df[col].apply(lambda x: x['subitem27']['mach'] if isinstance(x, dict) and 'subitem27' in x and 'mach' in x['subitem27'] else None)
                elif 'measured_flight_level' in df[col].values:
                    df['plots_max_measured_flight_level'] = df[col].apply(lambda x: x['measured_flight_level'] if isinstance(x, dict) and 'measured_flight_level' in x else None)
                df_final = df[['plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level']]
                    # print(df_final.head(5))
                    
        total_row = df_final.shape[0]
        # print("total row", total_row)
        if(total_row == 0):
            raise Exception("no data found, please check manually if it has correct format") 
        else:
            # Get Min All Values
            df_min = df_final.min()
    
            # Get Max All Values
            df_max = df_final.max()
            result = {}
            result = df_max.to_dict()
    
            # Get Total Duration
            df['time_of_track'] = pd.to_datetime(df['time_of_track'])
            total_duration = df['time_of_track'].max() - df['time_of_track'].min()
            hours = total_duration.seconds // 3600
            minutes = (total_duration.seconds % 3600) // 60
            seconds = total_duration.seconds % 60
            formatted_duration = f"{hours}h {minutes}m {seconds}s"
    
            # Append other data to dict
            result['id'] = id
            result['plots_duration'] = formatted_duration
    
            final_result = {
                'id': result['id'],
                'plots_duration': result['plots_duration'],
                'plots_max_altitude': result['plots_max_altitude'],
                'plots_max_baro_vert_rate': result['plots_max_baro_vert_rate'],
                'plots_max_mach': result['plots_max_mach'],
                'plots_max_measured_flight_level': result['plots_max_measured_flight_level'],
            }
            
            #return value
            return final_result, unique_aircraft_type, unique_flight_rules

# This is for testing purpose
file_name = '100000.json'
flight, unique_aircraft_type, unique_flight_rules = extract_data(folder_path+file_name)
print(flight, unique_aircraft_type, unique_flight_rules)
# Out:
# {'id': 100000, 'plots_duration': '0h 4m 14s', 'plots_max_altitude': 33000.0, 'plots_max_baro_vert_rate': 3325.0, 'plots_max_mach': 0.728, 'plots_max_measured_flight_level': 252.0} B738 I

# %% [markdown]
# ## Extract All JSON

# %%
counter_file = 0
max_file = 100
dict_result = {"flights": [], "unique_aircraft_type": [], "unique_flight_rules": []}
for file_name in json_files:
    if(counter_file < max_file):
        try:
            flight, unique_aircraft_type, unique_flight_rules = extract_data(folder_path+file_name)
            dict_result["flights"].append(flight)
            dict_result["unique_aircraft_type"].append(unique_aircraft_type)
            dict_result["unique_flight_rules"].append(unique_flight_rules)
            print("successfully extract file: ", str(folder_path+file_name))
        except Exception as e:
            print("error reading file: ", str(folder_path+file_name), str(e))
        counter_file += 1
    elif(counter_file >= max_file):
        break;
# Out:
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100000.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100001.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100002.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100003.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100004.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100005.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100006.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100007.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100008.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100009.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100010.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100011.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100012.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100013.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100014.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100015.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100016.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100017.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100018.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100019.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100020.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100021.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100022.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100023.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100024.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100025.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100026.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100027.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100028.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100029.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100030.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100031.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100032.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100033.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100034.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100035.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100036.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100037.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100038.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100039.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100040.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100041.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100042.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100043.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100044.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100045.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100046.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100047.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100048.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100049.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100050.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100051.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100052.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100053.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100054.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100055.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100056.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100057.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100058.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100059.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100060.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100061.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100062.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100063.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100064.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100065.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100066.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100068.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100069.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100070.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100071.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100072.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100074.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100075.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100076.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100077.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100078.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100079.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100080.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100081.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100082.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100083.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100084.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100085.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100086.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100087.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100088.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100089.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100090.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100091.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100092.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100093.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100094.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100095.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100096.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100097.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100098.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100099.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100100.json
# successfully extract file:  C:\Users\dmitr\Downloads\scat20161015_20161021\100101.json

# %% [markdown]
# ## Print Result

# %%
pp = pprint.PrettyPrinter(indent=2, width=30, compact=True)
pp.pprint(dict_result)
# Out:
# { 'flights': [ { 'id': 100000,
#                  'plots_duration': '0h '
#                                    '4m '
#                                    '14s',
#                  'plots_max_altitude': 33000.0,
#                  'plots_max_baro_vert_rate': 3325.0,
#                  'plots_max_mach': 0.728,
#                  'plots_max_measured_flight_level': 252.0},
#                { 'id': 100001,
#                  'plots_duration': '0h '
#                                    '29m '
#                                    '16s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 381.25,
#                  'plots_max_mach': 0.848,
#                  'plots_max_measured_flight_level': 350.0},
#                { 'id': 100002,
#                  'plots_duration': '0h '
#                                    '43m '
#                                    '40s',
#                  'plots_max_altitude': 41000.0,
#                  'plots_max_baro_vert_rate': 162.5,
#                  'plots_max_mach': 0.808,
#                  'plots_max_measured_flight_level': 410.0},
#                { 'id': 100003,
#                  'plots_duration': '0h '
#                                    '47m '
#                                    '59s',
#                  'plots_max_altitude': 37800.0,
#                  'plots_max_baro_vert_rate': 3006.25,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100004,
#                  'plots_duration': '0h '
#                                    '15m '
#                                    '54s',
#                  'plots_max_altitude': 19000.0,
#                  'plots_max_baro_vert_rate': 993.75,
#                  'plots_max_mach': 0.408,
#                  'plots_max_measured_flight_level': 190.0},
#                { 'id': 100005,
#                  'plots_duration': '0h '
#                                    '19m '
#                                    '5s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 606.25,
#                  'plots_max_mach': 0.848,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100006,
#                  'plots_duration': '0h '
#                                    '30m '
#                                    '26s',
#                  'plots_max_altitude': 40000.0,
#                  'plots_max_baro_vert_rate': 3293.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 400.0},
#                { 'id': 100007,
#                  'plots_duration': '0h '
#                                    '45m '
#                                    '18s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': 2206.25,
#                  'plots_max_mach': None,
#                  'plots_max_measured_flight_level': 200.0},
#                { 'id': 100008,
#                  'plots_duration': '0h '
#                                    '45m '
#                                    '44s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 3106.25,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 370.5},
#                { 'id': 100009,
#                  'plots_duration': '0h '
#                                    '49m '
#                                    '0s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 4000.0,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 350.0},
#                { 'id': 100010,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '58s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 1825.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100011,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '48s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 1406.25,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 361.0},
#                { 'id': 100012,
#                  'plots_duration': '0h '
#                                    '47m '
#                                    '50s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 543.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 370.25},
#                { 'id': 100013,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '9s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 4575.0,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 381.0},
#                { 'id': 100014,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '39s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 3075.0,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 371.0},
#                { 'id': 100015,
#                  'plots_duration': '0h '
#                                    '26m '
#                                    '45s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 4706.25,
#                  'plots_max_mach': 0.768,
#                  'plots_max_measured_flight_level': 350.0},
#                { 'id': 100016,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '24s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 418.75,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100017,
#                  'plots_duration': '1h '
#                                    '5m '
#                                    '29s',
#                  'plots_max_altitude': 16000.0,
#                  'plots_max_baro_vert_rate': 225.0,
#                  'plots_max_mach': 0.44,
#                  'plots_max_measured_flight_level': 160.25},
#                { 'id': 100018,
#                  'plots_duration': '0h '
#                                    '56m '
#                                    '15s',
#                  'plots_max_altitude': 175.0,
#                  'plots_max_baro_vert_rate': 2593.75,
#                  'plots_max_mach': 0.488,
#                  'plots_max_measured_flight_level': 180.25},
#                { 'id': 100019,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '29s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 800.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 390.25},
#                { 'id': 100020,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '40s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 162.5,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 390.0},
#                { 'id': 100021,
#                  'plots_duration': '0h '
#                                    '27m '
#                                    '5s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 3037.5,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 390.25},
#                { 'id': 100022,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '38s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 3393.75,
#                  'plots_max_mach': 0.776,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100023,
#                  'plots_duration': '0h '
#                                    '16m '
#                                    '50s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': -62.5,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 343.0},
#                { 'id': 100024,
#                  'plots_duration': '0h '
#                                    '49m '
#                                    '34s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 3200.0,
#                  'plots_max_mach': 0.824,
#                  'plots_max_measured_flight_level': 340.25},
#                { 'id': 100025,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '10s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 4225.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100026,
#                  'plots_duration': '0h '
#                                    '17m '
#                                    '50s',
#                  'plots_max_altitude': 22000.0,
#                  'plots_max_baro_vert_rate': 4287.5,
#                  'plots_max_mach': 0.584,
#                  'plots_max_measured_flight_level': 220.0},
#                { 'id': 100027,
#                  'plots_duration': '0h '
#                                    '44m '
#                                    '10s',
#                  'plots_max_altitude': 40000.0,
#                  'plots_max_baro_vert_rate': 4512.5,
#                  'plots_max_mach': 0.776,
#                  'plots_max_measured_flight_level': 400.0},
#                { 'id': 100028,
#                  'plots_duration': '0h '
#                                    '14m '
#                                    '9s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 706.25,
#                  'plots_max_mach': 0.776,
#                  'plots_max_measured_flight_level': 390.25},
#                { 'id': 100029,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '35s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 5537.5,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100030,
#                  'plots_duration': '0h '
#                                    '59m '
#                                    '35s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': 1981.25,
#                  'plots_max_mach': 0.504,
#                  'plots_max_measured_flight_level': 190.0},
#                { 'id': 100031,
#                  'plots_duration': '0h '
#                                    '12m '
#                                    '50s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 162.5,
#                  'plots_max_mach': 0.856,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100032,
#                  'plots_duration': '0h '
#                                    '36m '
#                                    '43s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 8193.75,
#                  'plots_max_mach': 0.816,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100033,
#                  'plots_duration': '0h '
#                                    '30m '
#                                    '18s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': 125.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100034,
#                  'plots_duration': '0h '
#                                    '35m '
#                                    '5s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': None,
#                  'plots_max_mach': None,
#                  'plots_max_measured_flight_level': 200.0},
#                { 'id': 100035,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '23s',
#                  'plots_max_altitude': 18100.0,
#                  'plots_max_baro_vert_rate': 2018.75,
#                  'plots_max_mach': 0.488,
#                  'plots_max_measured_flight_level': 180.25},
#                { 'id': 100036,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '40s',
#                  'plots_max_altitude': 37200.0,
#                  'plots_max_baro_vert_rate': 3650.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 361.0},
#                { 'id': 100037,
#                  'plots_duration': '0h '
#                                    '25m '
#                                    '0s',
#                  'plots_max_altitude': 40000.0,
#                  'plots_max_baro_vert_rate': 93.75,
#                  'plots_max_mach': 0.84,
#                  'plots_max_measured_flight_level': 400.0},
#                { 'id': 100038,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '19s',
#                  'plots_max_altitude': 40000.0,
#                  'plots_max_baro_vert_rate': 3968.75,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 400.0},
#                { 'id': 100039,
#                  'plots_duration': '0h '
#                                    '40m '
#                                    '29s',
#                  'plots_max_altitude': 41000.0,
#                  'plots_max_baro_vert_rate': 418.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 410.25},
#                { 'id': 100040,
#                  'plots_duration': '0h '
#                                    '10m '
#                                    '20s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 3837.5,
#                  'plots_max_mach': 0.728,
#                  'plots_max_measured_flight_level': 245.25},
#                { 'id': 100041,
#                  'plots_duration': '0h '
#                                    '35m '
#                                    '1s',
#                  'plots_max_altitude': 17000.0,
#                  'plots_max_baro_vert_rate': 8193.75,
#                  'plots_max_mach': 0.488,
#                  'plots_max_measured_flight_level': 170.0},
#                { 'id': 100042,
#                  'plots_duration': '0h '
#                                    '30m '
#                                    '15s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 1087.5,
#                  'plots_max_mach': 0.856,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100043,
#                  'plots_duration': '0h '
#                                    '15m '
#                                    '50s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 125.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 340.25},
#                { 'id': 100044,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '5s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 193.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 350.0},
#                { 'id': 100045,
#                  'plots_duration': '0h '
#                                    '24m '
#                                    '21s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 2687.5,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 360.25},
#                { 'id': 100046,
#                  'plots_duration': '0h '
#                                    '57m '
#                                    '49s',
#                  'plots_max_altitude': 28000.0,
#                  'plots_max_baro_vert_rate': 1406.25,
#                  'plots_max_mach': 0.624,
#                  'plots_max_measured_flight_level': 280.25},
#                { 'id': 100047,
#                  'plots_duration': '0h '
#                                    '50m '
#                                    '45s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 381.25,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 361.0},
#                { 'id': 100048,
#                  'plots_duration': '0h '
#                                    '47m '
#                                    '9s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 3875.0,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100049,
#                  'plots_duration': '0h '
#                                    '17m '
#                                    '35s',
#                  'plots_max_altitude': 10000.0,
#                  'plots_max_baro_vert_rate': 3518.75,
#                  'plots_max_mach': 0.448,
#                  'plots_max_measured_flight_level': 100.0},
#                { 'id': 100050,
#                  'plots_duration': '0h '
#                                    '25m '
#                                    '39s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 193.75,
#                  'plots_max_mach': 0.84,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100051,
#                  'plots_duration': '0h '
#                                    '22m '
#                                    '41s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 2781.25,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 360.25},
#                { 'id': 100052,
#                  'plots_duration': '0h '
#                                    '31m '
#                                    '45s',
#                  'plots_max_altitude': 33000.0,
#                  'plots_max_baro_vert_rate': 1918.75,
#                  'plots_max_mach': 0.84,
#                  'plots_max_measured_flight_level': 330.0},
#                { 'id': 100053,
#                  'plots_duration': '0h '
#                                    '29m '
#                                    '45s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 4093.75,
#                  'plots_max_mach': 0.848,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100054,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '40s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 4575.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 320.0},
#                { 'id': 100055,
#                  'plots_duration': '0h '
#                                    '33m '
#                                    '10s',
#                  'plots_max_altitude': 41550.0,
#                  'plots_max_baro_vert_rate': 3293.75,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 340.5},
#                { 'id': 100056,
#                  'plots_duration': '0h '
#                                    '46m '
#                                    '30s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 287.5,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100057,
#                  'plots_duration': '0h '
#                                    '7m '
#                                    '45s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': 3681.25,
#                  'plots_max_mach': 0.68,
#                  'plots_max_measured_flight_level': 214.0},
#                { 'id': 100058,
#                  'plots_duration': '1h '
#                                    '16m '
#                                    '14s',
#                  'plots_max_altitude': 22200.0,
#                  'plots_max_baro_vert_rate': 3006.25,
#                  'plots_max_mach': 0.488,
#                  'plots_max_measured_flight_level': 220.25},
#                { 'id': 100059,
#                  'plots_duration': '0h '
#                                    '33m '
#                                    '58s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 287.5,
#                  'plots_max_mach': 0.84,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100060,
#                  'plots_duration': '0h '
#                                    '49m '
#                                    '14s',
#                  'plots_max_altitude': 37925.0,
#                  'plots_max_baro_vert_rate': 4418.75,
#                  'plots_max_mach': 0.808,
#                  'plots_max_measured_flight_level': 340.0},
#                { 'id': 100061,
#                  'plots_duration': '0h '
#                                    '54m '
#                                    '9s',
#                  'plots_max_altitude': 27000.0,
#                  'plots_max_baro_vert_rate': 1375.0,
#                  'plots_max_mach': 0.632,
#                  'plots_max_measured_flight_level': 270.25},
#                { 'id': 100062,
#                  'plots_duration': '0h '
#                                    '39m '
#                                    '55s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 4225.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100063,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '59s',
#                  'plots_max_altitude': 38075.0,
#                  'plots_max_baro_vert_rate': 4381.25,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 381.0},
#                { 'id': 100064,
#                  'plots_duration': '0h '
#                                    '48m '
#                                    '14s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 6081.25,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100065,
#                  'plots_duration': '0h '
#                                    '32m '
#                                    '10s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 381.25,
#                  'plots_max_mach': 0.856,
#                  'plots_max_measured_flight_level': 350.0},
#                { 'id': 100066,
#                  'plots_duration': '0h '
#                                    '48m '
#                                    '25s',
#                  'plots_max_altitude': 35000.0,
#                  'plots_max_baro_vert_rate': 3712.5,
#                  'plots_max_mach': 0.768,
#                  'plots_max_measured_flight_level': 350.25},
#                { 'id': 100068,
#                  'plots_duration': '0h '
#                                    '28m '
#                                    '44s',
#                  'plots_max_altitude': 18000.0,
#                  'plots_max_baro_vert_rate': 2562.5,
#                  'plots_max_mach': 0.472,
#                  'plots_max_measured_flight_level': 140.5},
#                { 'id': 100069,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '9s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': 2718.75,
#                  'plots_max_mach': 0.712,
#                  'plots_max_measured_flight_level': 290.25},
#                { 'id': 100070,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '4s',
#                  'plots_max_altitude': 27000.0,
#                  'plots_max_baro_vert_rate': 2337.5,
#                  'plots_max_mach': 0.672,
#                  'plots_max_measured_flight_level': 270.25},
#                { 'id': 100071,
#                  'plots_duration': '0h '
#                                    '30m '
#                                    '11s',
#                  'plots_max_altitude': 13000.0,
#                  'plots_max_baro_vert_rate': 1631.25,
#                  'plots_max_mach': 0.456,
#                  'plots_max_measured_flight_level': 130.0},
#                { 'id': 100072,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '25s',
#                  'plots_max_altitude': 32000.0,
#                  'plots_max_baro_vert_rate': 4193.75,
#                  'plots_max_mach': 0.768,
#                  'plots_max_measured_flight_level': 320.0},
#                { 'id': 100074,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '44s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 4031.25,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 360.25},
#                { 'id': 100075,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '19s',
#                  'plots_max_altitude': 31000.0,
#                  'plots_max_baro_vert_rate': 2818.75,
#                  'plots_max_mach': 0.688,
#                  'plots_max_measured_flight_level': 310.25},
#                { 'id': 100076,
#                  'plots_duration': '0h '
#                                    '13m '
#                                    '40s',
#                  'plots_max_altitude': 12000.0,
#                  'plots_max_baro_vert_rate': -162.5,
#                  'plots_max_mach': 0.696,
#                  'plots_max_measured_flight_level': 245.0},
#                { 'id': 100077,
#                  'plots_duration': '0h '
#                                    '15m '
#                                    '54s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': 1312.5,
#                  'plots_max_mach': None,
#                  'plots_max_measured_flight_level': 110.25},
#                { 'id': 100078,
#                  'plots_duration': '1h '
#                                    '9m '
#                                    '21s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': None,
#                  'plots_max_mach': None,
#                  'plots_max_measured_flight_level': 140.0},
#                { 'id': 100079,
#                  'plots_duration': '1h '
#                                    '3m '
#                                    '24s',
#                  'plots_max_altitude': None,
#                  'plots_max_baro_vert_rate': None,
#                  'plots_max_mach': None,
#                  'plots_max_measured_flight_level': 180.0},
#                { 'id': 100080,
#                  'plots_duration': '0h '
#                                    '39m '
#                                    '35s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 5025.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100081,
#                  'plots_duration': '0h '
#                                    '18m '
#                                    '39s',
#                  'plots_max_altitude': 40000.0,
#                  'plots_max_baro_vert_rate': 706.25,
#                  'plots_max_mach': 0.848,
#                  'plots_max_measured_flight_level': 400.0},
#                { 'id': 100082,
#                  'plots_duration': '0h '
#                                    '18m '
#                                    '59s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 3581.25,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100083,
#                  'plots_duration': '0h '
#                                    '38m '
#                                    '4s',
#                  'plots_max_altitude': 41000.0,
#                  'plots_max_baro_vert_rate': 3618.75,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 410.0},
#                { 'id': 100084,
#                  'plots_duration': '0h '
#                                    '30m '
#                                    '24s',
#                  'plots_max_altitude': 19000.0,
#                  'plots_max_baro_vert_rate': 1918.75,
#                  'plots_max_mach': 0.448,
#                  'plots_max_measured_flight_level': 190.0},
#                { 'id': 100085,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '49s',
#                  'plots_max_altitude': 30000.0,
#                  'plots_max_baro_vert_rate': 3293.75,
#                  'plots_max_mach': 0.688,
#                  'plots_max_measured_flight_level': 300.0},
#                { 'id': 100086,
#                  'plots_duration': '0h '
#                                    '45m '
#                                    '5s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 1087.5,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 340.25},
#                { 'id': 100087,
#                  'plots_duration': '0h '
#                                    '20m '
#                                    '33s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': 0.0,
#                  'plots_max_mach': 0.832,
#                  'plots_max_measured_flight_level': 320.25},
#                { 'id': 100088,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '20s',
#                  'plots_max_altitude': 24000.0,
#                  'plots_max_baro_vert_rate': 2850.0,
#                  'plots_max_mach': 0.576,
#                  'plots_max_measured_flight_level': 240.0},
#                { 'id': 100089,
#                  'plots_duration': '0h '
#                                    '43m '
#                                    '2s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 543.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 380.5},
#                { 'id': 100090,
#                  'plots_duration': '0h '
#                                    '17m '
#                                    '30s',
#                  'plots_max_altitude': 12000.0,
#                  'plots_max_baro_vert_rate': 93.75,
#                  'plots_max_mach': 0.584,
#                  'plots_max_measured_flight_level': 176.25},
#                { 'id': 100091,
#                  'plots_duration': '0h '
#                                    '36m '
#                                    '0s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 1437.5,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 390.25},
#                { 'id': 100092,
#                  'plots_duration': '0h '
#                                    '25m '
#                                    '49s',
#                  'plots_max_altitude': 15000.0,
#                  'plots_max_baro_vert_rate': 1793.75,
#                  'plots_max_mach': 0.48,
#                  'plots_max_measured_flight_level': 150.25},
#                { 'id': 100093,
#                  'plots_duration': '0h '
#                                    '35m '
#                                    '3s',
#                  'plots_max_altitude': 36000.0,
#                  'plots_max_baro_vert_rate': 318.75,
#                  'plots_max_mach': 0.848,
#                  'plots_max_measured_flight_level': 360.0},
#                { 'id': 100094,
#                  'plots_duration': '0h '
#                                    '42m '
#                                    '40s',
#                  'plots_max_altitude': 38000.0,
#                  'plots_max_baro_vert_rate': 162.5,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 380.0},
#                { 'id': 100095,
#                  'plots_duration': '0h '
#                                    '52m '
#                                    '59s',
#                  'plots_max_altitude': 16000.0,
#                  'plots_max_baro_vert_rate': 1250.0,
#                  'plots_max_mach': 0.488,
#                  'plots_max_measured_flight_level': 160.5},
#                { 'id': 100096,
#                  'plots_duration': '0h '
#                                    '57m '
#                                    '9s',
#                  'plots_max_altitude': 35725.0,
#                  'plots_max_baro_vert_rate': 1025.0,
#                  'plots_max_mach': 0.624,
#                  'plots_max_measured_flight_level': 280.25},
#                { 'id': 100097,
#                  'plots_duration': '0h '
#                                    '57m '
#                                    '35s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 193.75,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 390.0},
#                { 'id': 100098,
#                  'plots_duration': '0h '
#                                    '41m '
#                                    '54s',
#                  'plots_max_altitude': 37000.0,
#                  'plots_max_baro_vert_rate': 287.5,
#                  'plots_max_mach': 0.784,
#                  'plots_max_measured_flight_level': 370.0},
#                { 'id': 100099,
#                  'plots_duration': '0h '
#                                    '49m '
#                                    '40s',
#                  'plots_max_altitude': 39000.0,
#                  'plots_max_baro_vert_rate': 768.75,
#                  'plots_max_mach': 0.792,
#                  'plots_max_measured_flight_level': 391.0},
#                { 'id': 100100,
#                  'plots_duration': '0h '
#                                    '31m '
#                                    '51s',
#                  'plots_max_altitude': 29000.0,
#                  'plots_max_baro_vert_rate': 575.0,
#                  'plots_max_mach': 0.84,
#                  'plots_max_measured_flight_level': 290.0},
#                { 'id': 100101,
#                  'plots_duration': '0h '
#                                    '40m '
#                                    '50s',
#                  'plots_max_altitude': 34000.0,
#                  'plots_max_baro_vert_rate': 3200.0,
#                  'plots_max_mach': 0.8,
#                  'plots_max_measured_flight_level': 340.0}],
#   'unique_aircraft_type': [ 'B738',
#                             'B772',
#                             'B737',
#                             'CRJ9',
#                             'AT76',
#                             'B772',
#                             'B736',
#                             'AT45',
#                             'A321',
#                             'B738',
#                             'B738',
#                             'A321',
#                             'A320',
#                             'A319',
#                             'A320',
#                             'B738',
#                             'B738',
#                             'ATP',
#                             'AT75',
#                             'B738',
#                             'B737',
#                             'A319',
#                             'B736',
#                             'A320',
#                             'CRJ9',
#                             'B738',
#                             'B737',
#                             'B737',
#                             'B738',
#                             'B737',
#                             'AT75',
#                             'B77W',
#                             'B738',
#                             'B738',
#                             'SF34',
#                             'AT76',
#                             'B738',
#                             'B772',
#                             'B736',
#                             'B738',
#                             'B738',
#                             'AT76',
#                             'A388',
#                             'CRJ9',
#                             'CRJ9',
#                             'CRJ9',
#                             'SB20',
#                             'A320',
#                             'B738',
#                             'AT72',
#                             'B77W',
#                             'B738',
#                             'B77W',
#                             'B77W',
#                             'A320',
#                             'A321',
#                             'B738',
#                             'A321',
#                             'AT45',
#                             'B77W',
#                             'B738',
#                             'SB20',
#                             'B739',
#                             'A319',
#                             'B737',
#                             'B789',
#                             'A321',
#                             'AT76',
#                             'RJ1H',
#                             'RJ1H',
#                             'AT76',
#                             'B738',
#                             'A321',
#                             'RJ85',
#                             'CRJ7',
#                             'AT72',
#                             'JS32',
#                             'JS32',
#                             'B738',
#                             'B789',
#                             'A319',
#                             'E190',
#                             'AT76',
#                             'RJ1H',
#                             'A320',
#                             'B77W',
#                             'DH8D',
#                             'A320',
#                             'B77W',
#                             'B738',
#                             'AT75',
#                             'B77W',
#                             'A319',
#                             'AT76',
#                             'SB20',
#                             'B737',
#                             'B738',
#                             'A319',
#                             'B77L',
#                             'B738'],
#   'unique_flight_rules': [ 'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I',
#                            'I']}
