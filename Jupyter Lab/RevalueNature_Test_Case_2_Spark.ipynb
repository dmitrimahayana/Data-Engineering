# %% [markdown]
# # Use Case 1 - Summary of All Flight

# %% [markdown]
# ## Initialization

# %%
import os, json
import pandas as pd
import pprint
from pyspark.sql import SparkSession, Window
from pyspark.sql.types import IntegerType, StringType, FloatType, DoubleType, ArrayType, LongType
from pyspark.sql.functions import col, concat, concat_ws, max, min, posexplode, arrays_zip, to_timestamp, exp, unix_timestamp, lit

# %% [markdown]
# ## Assumption

# %% [markdown]
# ##### 1. One file is 1 flight id hence there is no way multiple flight in single file
# ##### 2. All file in json format and located under specific folder

# %% [markdown]
# ## Load Dataset

# %%
# Initialize Spark Session
sparkMaster = 'spark://192.168.1.4:7077'
sparkAppName = 'Py-RevalueNature-Case2'
spark = SparkSession \
    .builder \
    .master(sparkMaster) \
    .appName(sparkAppName) \
    .getOrCreate()

# %%
# Read all dataset
folder_path = 'D:\\00 Project\\00 My Project\\Dataset\\Revalue Nature\\Case 2\\' # Assuming this where all json file will be stored
file_name = '*.json' # Naming file convention
df_source = spark.read.json(folder_path + file_name, multiLine=True) # Read all json files
df_source.printSchema()

# %% [markdown]
# ## Extract Data Function

# %%
def extract_data(df_source):
    # Extract important columns
    df_result1 = (df_source
                  .withColumn('id', col('id')) \
                  .withColumn('list_altitude', col('plots.I062/380.subitem7.altitude').cast(ArrayType(DoubleType())))
                  .withColumn('list_baro_vert_rate', col('plots.I062/380.subitem13.baro_vert_rate').cast(ArrayType(DoubleType())))
                  .withColumn('list_mach', col('plots.I062/380.subitem27.mach').cast(ArrayType(DoubleType())))
                  .withColumn('list_measured_flight_level', col('plots.I062/136.measured_flight_level').cast(ArrayType(DoubleType())))
                  .withColumn('list_start_time', col('centre_ctrl.start_time').cast(ArrayType(StringType())))
                  .withColumn('list_time_of_track', col('plots.time_of_track').cast(ArrayType(StringType())))
                  .withColumn('list_aircraft_type', col('fpl.fpl_base.aircraft_type'))
                  .withColumn('list_flight_rules', col('fpl.fpl_base.flight_rules'))
                )

    # Transform into new columns
    df_result2 = (df_result1
                  .withColumn("tmp", arrays_zip("list_altitude", "list_baro_vert_rate", "list_mach", "list_measured_flight_level", "list_time_of_track")) # ZIP array columns
                  .withColumn("tmp", explode("tmp")) # explode the array
                  .withColumn('plots_max_altitude', max(col("tmp.list_altitude")).over(Window.partitionBy('id'))) # get max altitude by id
                  .withColumn('plots_max_baro_vert_rate', max(col("tmp.list_baro_vert_rate")).over(Window.partitionBy('id'))) # get max baro_vert_rate by id
                  .withColumn('plots_max_mach', max(col("tmp.list_mach")).over(Window.partitionBy('id'))) # get max mach by id
                  .withColumn('plots_max_measured_flight_level', max(col("tmp.list_measured_flight_level")).over(Window.partitionBy('id'))) # get max measured_flight_level by id
                  .withColumn("start_time", to_timestamp(df_result1["list_start_time"].getItem(0))) # get start time
                  .withColumn('end_time', max(to_timestamp(col("tmp.list_time_of_track"))).over(Window.partitionBy('id'))) # get end time
                  .withColumn("duration_s", unix_timestamp("end_time") - unix_timestamp("start_time")) # get durations in second
                  .withColumn("duration_h", concat(expr("duration_s / 3600").cast(IntegerType()), lit("h")))
                  .withColumn("duration_m", concat(expr("(duration_s % 3600) / 60").cast(IntegerType()), lit("m")))
                  .withColumn("duration_s", concat(expr("duration_s % 60").cast(IntegerType()), lit("s")))
                  .withColumn("plots_duration", concat_ws(' ',col("duration_h"), col("duration_m"), col("duration_s"))) # get all durations
                  .withColumn('aircraft_type', df_result1["list_aircraft_type"].getItem(0)) # get aircraft type
                  .withColumn('flight_rules', df_result1["list_flight_rules"].getItem(0)) # get aircraft type
                 )
    
    df_result2 = df_result2.select('id', 'plots_duration', 'plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level', 'aircraft_type', 'flight_rules').distinct()
    return df_result2

df_test_input = spark.read.json(folder_path + '10000*.json', multiLine=True) # Read all json files
df_test_result = extract_data(df_test_input)
print(df_test_result.show())
# Out:
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
# |    id|plots_duration|plots_max_altitude|plots_max_baro_vert_rate|plots_max_mach|plots_max_measured_flight_level|aircraft_type|flight_rules|
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
# |100000|     0h 6m 26s|           33000.0|                  3325.0|         0.728|                          252.0|         B738|           I|
# |100001|     0h 32m 5s|           35000.0|                  381.25|         0.848|                          350.0|         B772|           I|
# |100002|     0h 47m 0s|           41000.0|                   162.5|         0.808|                          410.0|         B737|           I|
# |100003|    0h 49m 52s|           37800.0|                 3006.25|         0.792|                          340.0|         CRJ9|           I|
# |100004|    0h 18m 45s|           19000.0|                  993.75|         0.408|                          190.0|         AT76|           I|
# |100005|    0h 20m 34s|           34000.0|                  606.25|         0.848|                          340.0|         B772|           I|
# |100006|    0h 30m 33s|           40000.0|                 3293.75|         0.792|                          400.0|         B736|           I|
# |100007|    0h 51m 44s|              null|                 2206.25|          null|                          200.0|         AT45|           I|
# |100008|     0h 46m 6s|           37000.0|                 3106.25|           0.8|                          370.5|         A321|           I|
# |100009|    0h 50m 18s|           35000.0|                  4000.0|         0.792|                          350.0|         B738|           I|
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
#
# None

# %% [markdown]
# ## Prepare Final Result

# %%
def prepare_result(df_source):
    # Select flights columns
    df_flights = df_source.select('id', 'plots_duration', 'plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level')
    # print(df_flights.show())
    
    # Select unique_aircraft_type columns
    df_aircraft_type = df_source.select('aircraft_type')
    # print(df_aircraft_type.show())
    
    # Select unique_flight_rules columns
    df_flight_rules = df_source.select('flight_rules')
    # print(df_flight_rules.show())
    
    # Convert to json format
    json_flights = df_flights.toPandas().to_json(orient='records')
    list_unique_aircraft_type = df_aircraft_type.toPandas()['aircraft_type'].tolist()
    list_unique_flight_rules = df_flight_rules.toPandas()['flight_rules'].tolist()
    # pprint.pprint(json_flights)
    # print(list_unique_aircraft_type)
    # print(list_unique_flight_rules)
    
    # Initialize Dictionary Result
    dict_result = {"flights": '', "unique_aircraft_type": '', "unique_flight_rules": ''}
    
    # Test dictionary
    dict_result["flights"] = json_flights
    dict_result["unique_aircraft_type"] = list_unique_aircraft_type
    dict_result["unique_flight_rules"] = list_unique_flight_rules

    return dict_result

# This is for testing purpose
dict_result = prepare_result(df_test_result)
pprint.pprint(dict_result)
# Out:
# {'flights': '[{"id":100000,"plots_duration":"0h 6m '
#             '26s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":3325.0,"plots_max_mach":0.728,"plots_max_measured_flight_level":252.0},{"id":100001,"plots_duration":"0h '
#             '32m '
#             '5s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.848,"plots_max_measured_flight_level":350.0},{"id":100002,"plots_duration":"0h '
#             '47m '
#             '0s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":410.0},{"id":100003,"plots_duration":"0h '
#             '49m '
#             '52s","plots_max_altitude":37800.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":340.0},{"id":100004,"plots_duration":"0h '
#             '18m '
#             '45s","plots_max_altitude":19000.0,"plots_max_baro_vert_rate":993.75,"plots_max_mach":0.408,"plots_max_measured_flight_level":190.0},{"id":100005,"plots_duration":"0h '
#             '20m '
#             '34s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.848,"plots_max_measured_flight_level":340.0},{"id":100006,"plots_duration":"0h '
#             '30m '
#             '33s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":3293.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0},{"id":100007,"plots_duration":"0h '
#             '51m '
#             '44s","plots_max_altitude":null,"plots_max_baro_vert_rate":2206.25,"plots_max_mach":null,"plots_max_measured_flight_level":200.0},{"id":100008,"plots_duration":"0h '
#             '46m '
#             '6s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3106.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.5},{"id":100009,"plots_duration":"0h '
#             '50m '
#             '18s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4000.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":350.0}]',
#  'unique_aircraft_type': ['B738',
#                           'B772',
#                           'B737',
#                           'CRJ9',
#                           'AT76',
#                           'B772',
#                           'B736',
#                           'AT45',
#                           'A321',
#                           'B738'],
#  'unique_flight_rules': ['I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I']}

# %% [markdown]
# ## Extract and Transforms All Data

# %%
df_extraction = extract_data(df_source)
print("Total Data: ",df_extraction.count())

# %%
dict_result = prepare_result(df_extraction)
pprint.pprint(dict_result)
# Out:
# {'flights': '[{"id":100200,"plots_duration":"0h 30m '
#             '18s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.848,"plots_max_measured_flight_level":310.0},{"id":100201,"plots_duration":"0h '
#             '49m '
#             '0s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":1218.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":361.0},{"id":100202,"plots_duration":"0h '
#             '16m '
#             '15s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":-2462.5,"plots_max_mach":0.696,"plots_max_measured_flight_level":214.25},{"id":100203,"plots_duration":"0h '
#             '19m '
#             '12s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":110.25},{"id":100204,"plots_duration":"0h '
#             '33m '
#             '4s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.656,"plots_max_measured_flight_level":290.0},{"id":100205,"plots_duration":"0h '
#             '38m '
#             '25s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":390.0},{"id":100206,"plots_duration":"0h '
#             '40m '
#             '37s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":3650.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0},{"id":100207,"plots_duration":"0h '
#             '51m '
#             '28s","plots_max_altitude":23000.0,"plots_max_baro_vert_rate":2687.5,"plots_max_mach":0.552,"plots_max_measured_flight_level":230.25},{"id":100208,"plots_duration":"0h '
#             '24m '
#             '13s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":350.0},{"id":100209,"plots_duration":"0h '
#             '46m '
#             '33s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":1218.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.0},{"id":100210,"plots_duration":"0h '
#             '19m '
#             '26s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3906.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":368.75},{"id":100211,"plots_duration":"0h '
#             '50m '
#             '47s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":831.25,"plots_max_mach":0.704,"plots_max_measured_flight_level":310.25},{"id":100212,"plots_duration":"0h '
#             '41m '
#             '16s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":361.0},{"id":100213,"plots_duration":"0h '
#             '35m '
#             '29s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.0},{"id":100214,"plots_duration":"0h '
#             '49m '
#             '43s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":381.0},{"id":100215,"plots_duration":"0h '
#             '24m '
#             '36s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3231.25,"plots_max_mach":0.864,"plots_max_measured_flight_level":369.5},{"id":100217,"plots_duration":"0h '
#             '53m '
#             '26s","plots_max_altitude":15000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.472,"plots_max_measured_flight_level":150.0},{"id":100218,"plots_duration":"0h '
#             '46m '
#             '28s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":370.0},{"id":100219,"plots_duration":"0h '
#             '54m '
#             '8s","plots_max_altitude":19000.0,"plots_max_baro_vert_rate":1693.75,"plots_max_mach":0.496,"plots_max_measured_flight_level":190.25},{"id":100220,"plots_duration":"0h '
#             '20m '
#             '41s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":351.0},{"id":100221,"plots_duration":"0h '
#             '23m '
#             '42s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":271.0},{"id":100222,"plots_duration":"0h '
#             '53m '
#             '51s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":800.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0},{"id":100223,"plots_duration":"0h '
#             '43m '
#             '32s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4993.75,"plots_max_mach":0.768,"plots_max_measured_flight_level":390.0},{"id":100224,"plots_duration":"0h '
#             '31m '
#             '38s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":4031.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":320.0},{"id":100225,"plots_duration":"0h '
#             '25m '
#             '56s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":-162.5,"plots_max_mach":0.848,"plots_max_measured_flight_level":396.0},{"id":100226,"plots_duration":"0h '
#             '53m '
#             '4s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":800.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":340.0},{"id":100227,"plots_duration":"0h '
#             '47m '
#             '56s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.92,"plots_max_measured_flight_level":370.0},{"id":100228,"plots_duration":"0h '
#             '34m '
#             '28s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":1312.5,"plots_max_mach":0.84,"plots_max_measured_flight_level":380.25},{"id":100229,"plots_duration":"0h '
#             '24m '
#             '49s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.0},{"id":100230,"plots_duration":"0h '
#             '41m '
#             '56s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":4737.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":340.0},{"id":100231,"plots_duration":"0h '
#             '56m '
#             '40s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":3293.75,"plots_max_mach":0.672,"plots_max_measured_flight_level":310.25},{"id":100232,"plots_duration":"0h '
#             '35m '
#             '18s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.832,"plots_max_measured_flight_level":360.0},{"id":100233,"plots_duration":"1h '
#             '7m '
#             '25s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":1406.25,"plots_max_mach":0.784,"plots_max_measured_flight_level":350.0},{"id":100235,"plots_duration":"0h '
#             '18m '
#             '25s","plots_max_altitude":8000.0,"plots_max_baro_vert_rate":-450.0,"plots_max_mach":0.584,"plots_max_measured_flight_level":180.0},{"id":100236,"plots_duration":"0h '
#             '15m '
#             '23s","plots_max_altitude":5000.0,"plots_max_baro_vert_rate":-287.5,"plots_max_mach":0.528,"plots_max_measured_flight_level":103.25},{"id":100237,"plots_duration":"0h '
#             '11m '
#             '33s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":4418.75,"plots_max_mach":0.728,"plots_max_measured_flight_level":310.0},{"id":100238,"plots_duration":"0h '
#             '54m '
#             '39s","plots_max_altitude":26000.0,"plots_max_baro_vert_rate":2912.5,"plots_max_mach":0.616,"plots_max_measured_flight_level":260.25},{"id":100239,"plots_duration":"0h '
#             '44m '
#             '18s","plots_max_altitude":25000.0,"plots_max_baro_vert_rate":3837.5,"plots_max_mach":0.704,"plots_max_measured_flight_level":250.0},{"id":100240,"plots_duration":"0h '
#             '48m '
#             '38s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0},{"id":100241,"plots_duration":"0h '
#             '51m '
#             '49s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":390.25},{"id":100242,"plots_duration":"0h '
#             '48m '
#             '2s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":351.0},{"id":100243,"plots_duration":"0h '
#             '47m '
#             '14s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":1118.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":380.0},{"id":100244,"plots_duration":"0h '
#             '2m '
#             '44s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":3037.5,"plots_max_mach":0.704,"plots_max_measured_flight_level":211.0},{"id":100245,"plots_duration":"0h '
#             '38m '
#             '47s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":5312.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":380.25},{"id":100246,"plots_duration":"0h '
#             '56m '
#             '23s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":170.0},{"id":100247,"plots_duration":"0h '
#             '39m '
#             '12s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.776,"plots_max_measured_flight_level":371.0},{"id":100248,"plots_duration":"0h '
#             '46m '
#             '29s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4062.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":330.0},{"id":100249,"plots_duration":"0h '
#             '19m '
#             '15s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.632,"plots_max_measured_flight_level":237.0},{"id":100250,"plots_duration":"0h '
#             '46m '
#             '7s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":62.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":350.25},{"id":100251,"plots_duration":"0h '
#             '28m '
#             '49s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.752,"plots_max_measured_flight_level":341.0},{"id":100252,"plots_duration":"0h '
#             '38m '
#             '5s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":1437.5,"plots_max_mach":0.816,"plots_max_measured_flight_level":380.0},{"id":100253,"plots_duration":"0h '
#             '34m '
#             '20s","plots_max_altitude":30000.0,"plots_max_baro_vert_rate":4893.75,"plots_max_mach":0.84,"plots_max_measured_flight_level":300.0},{"id":100255,"plots_duration":"1h '
#             '3m '
#             '7s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":180.0},{"id":100256,"plots_duration":"0h '
#             '47m '
#             '28s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.25},{"id":100257,"plots_duration":"0h '
#             '46m '
#             '10s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0},{"id":100258,"plots_duration":"0h '
#             '46m '
#             '22s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0},{"id":100259,"plots_duration":"0h '
#             '44m '
#             '31s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.856,"plots_max_measured_flight_level":350.0},{"id":100260,"plots_duration":"0h '
#             '33m '
#             '32s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.872,"plots_max_measured_flight_level":380.0},{"id":100261,"plots_duration":"0h '
#             '46m '
#             '16s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":340.25},{"id":100262,"plots_duration":"0h '
#             '54m '
#             '2s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4162.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":350.0},{"id":100263,"plots_duration":"0h '
#             '31m '
#             '53s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0},{"id":100264,"plots_duration":"0h '
#             '51m '
#             '19s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":3906.25,"plots_max_mach":0.76,"plots_max_measured_flight_level":330.0},{"id":100265,"plots_duration":"0h '
#             '42m '
#             '43s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":371.0},{"id":100266,"plots_duration":"0h '
#             '22m '
#             '28s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":340.0},{"id":100267,"plots_duration":"0h '
#             '39m '
#             '47s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3681.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":390.5},{"id":100268,"plots_duration":"0h '
#             '53m '
#             '13s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":2562.5,"plots_max_mach":0.48,"plots_max_measured_flight_level":170.5},{"id":100269,"plots_duration":"1h '
#             '6m '
#             '41s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":410.0},{"id":100270,"plots_duration":"0h '
#             '32m '
#             '7s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":2306.25,"plots_max_mach":0.784,"plots_max_measured_flight_level":350.0},{"id":100271,"plots_duration":"0h '
#             '23m '
#             '0s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3231.25,"plots_max_mach":0.808,"plots_max_measured_flight_level":360.0},{"id":100272,"plots_duration":"0h '
#             '49m '
#             '2s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.0},{"id":100273,"plots_duration":"0h '
#             '35m '
#             '5s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.824,"plots_max_measured_flight_level":380.0},{"id":100274,"plots_duration":"0h '
#             '24m '
#             '37s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":2818.75,"plots_max_mach":0.752,"plots_max_measured_flight_level":360.0},{"id":100275,"plots_duration":"0h '
#             '8m '
#             '46s","plots_max_altitude":2500.0,"plots_max_baro_vert_rate":-162.5,"plots_max_mach":0.392,"plots_max_measured_flight_level":83.0},{"id":100276,"plots_duration":"0h '
#             '42m '
#             '52s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3875.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":370.25},{"id":100277,"plots_duration":"0h '
#             '46m '
#             '34s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3362.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":371.0},{"id":100278,"plots_duration":"0h '
#             '42m '
#             '50s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4093.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.25},{"id":100279,"plots_duration":"0h '
#             '44m '
#             '42s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":390.0},{"id":100280,"plots_duration":"0h '
#             '47m '
#             '42s","plots_max_altitude":null,"plots_max_baro_vert_rate":null,"plots_max_mach":null,"plots_max_measured_flight_level":131.0},{"id":100281,"plots_duration":"0h '
#             '25m '
#             '49s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3168.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.25},{"id":100282,"plots_duration":"0h '
#             '26m '
#             '19s","plots_max_altitude":49975.0,"plots_max_baro_vert_rate":4925.0,"plots_max_mach":0.696,"plots_max_measured_flight_level":340.0},{"id":100283,"plots_duration":"0h '
#             '28m '
#             '18s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":2718.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.25},{"id":100284,"plots_duration":"0h '
#             '33m '
#             '15s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0},{"id":100285,"plots_duration":"0h '
#             '39m '
#             '46s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0},{"id":100286,"plots_duration":"0h '
#             '37m '
#             '11s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.816,"plots_max_measured_flight_level":361.0},{"id":100287,"plots_duration":"0h '
#             '56m '
#             '49s","plots_max_altitude":24000.0,"plots_max_baro_vert_rate":3262.5,"plots_max_mach":0.56,"plots_max_measured_flight_level":240.25},{"id":100288,"plots_duration":"0h '
#             '56m '
#             '1s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4962.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.0},{"id":100289,"plots_duration":"0h '
#             '41m '
#             '56s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3743.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":360.0},{"id":100290,"plots_duration":"0h '
#             '37m '
#             '30s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.856,"plots_max_measured_flight_level":360.0},{"id":100291,"plots_duration":"0h '
#             '43m '
#             '51s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4543.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":380.0},{"id":100292,"plots_duration":"0h '
#             '51m '
#             '13s","plots_max_altitude":16000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.488,"plots_max_measured_flight_level":160.25},{"id":100293,"plots_duration":"0h '
#             '22m '
#             '3s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":575.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":370.25},{"id":100294,"plots_duration":"0h '
#             '42m '
#             '21s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4512.5,"plots_max_mach":0.76,"plots_max_measured_flight_level":360.0},{"id":100295,"plots_duration":"0h '
#             '52m '
#             '1s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":2912.5,"plots_max_mach":0.68,"plots_max_measured_flight_level":290.25},{"id":100296,"plots_duration":"0h '
#             '24m '
#             '2s","plots_max_altitude":10000.0,"plots_max_baro_vert_rate":-831.25,"plots_max_mach":0.768,"plots_max_measured_flight_level":361.0},{"id":100297,"plots_duration":"0h '
#             '25m '
#             '18s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":2781.25,"plots_max_mach":0.848,"plots_max_measured_flight_level":310.0},{"id":100298,"plots_duration":"0h '
#             '44m '
#             '37s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":410.0},{"id":100299,"plots_duration":"0h '
#             '17m '
#             '34s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":31.25,"plots_max_mach":0.632,"plots_max_measured_flight_level":204.75}]',
#  'unique_aircraft_type': ['B77W',
#                           'A320',
#                           'A320',
#                           'AT72',
#                           'B738',
#                           'A333',
#                           'B738',
#                           'DH8D',
#                           'B739',
#                           'B738',
#                           'A320',
#                           'RJ1H',
#                           'A320',
#                           'B738',
#                           'B738',
#                           'B788',
#                           'AT76',
#                           'B738',
#                           'AT76',
#                           'B772',
#                           'B463',
#                           'B738',
#                           'E170',
#                           'A306',
#                           'B788',
#                           'B738',
#                           'B738',
#                           'B77W',
#                           'B738',
#                           'B738',
#                           'RJ1H',
#                           'B77W',
#                           'B738',
#                           'E190',
#                           'B738',
#                           'CRJ9',
#                           'SB20',
#                           'B738',
#                           'B738',
#                           'A320',
#                           'A321',
#                           'B738',
#                           'A320',
#                           'B737',
#                           'SF34',
#                           'A319',
#                           'B738',
#                           'A320',
#                           'A321',
#                           'A321',
#                           'A332',
#                           'B763',
#                           'F50',
#                           'A319',
#                           'B738',
#                           'E190',
#                           'B789',
#                           'B744',
#                           'A320',
#                           'B738',
#                           'E190',
#                           'B737',
#                           'A320',
#                           'CRJ9',
#                           'A319',
#                           'AT76',
#                           'B736',
#                           'B738',
#                           'B738',
#                           'B737',
#                           'A333',
#                           'A321',
#                           'ATP',
#                           'A320',
#                           'A320',
#                           'B736',
#                           'B737',
#                           'JS32',
#                           'CRJ9',
#                           'B738',
#                           'A319',
#                           'B738',
#                           'B738',
#                           'A321',
#                           'DH8D',
#                           'B736',
#                           'B736',
#                           'B77W',
#                           'B738',
#                           'AT76',
#                           'A320',
#                           'B738',
#                           'A320',
#                           'B738',
#                           'B77W',
#                           'B736',
#                           'CRJ9'],
#  'unique_flight_rules': ['I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I',
#                          'I']}
