# %% [markdown]
# # Use Case 1 - Summary of All Flight

# %% [markdown]
# ## Initialization

# %%
import os, json
import pandas as pd
import pprint
from pyspark.sql import SparkSession, Window
from pyspark.sql.types import IntegerType, StringType, FloatType, DoubleType, ArrayType, LongType
from pyspark.sql.functions import col, concat, concat_ws, max, min, explode, arrays_zip, to_timestamp, expr, unix_timestamp, lit

# %% [markdown]
# ## Assumption

# %% [markdown]
# ##### 1. One file is 1 flight id, so there is no way multiple flight in single file
# ##### 2. All files are json format and located under specific folder

# %% [markdown]
# ## Load Dataset

# %%
# Initialize Spark Session
sparkMaster = 'spark://192.168.1.4:7077'
sparkAppName = 'Py-RevalueNature-Case2'
spark = SparkSession \
    .builder \
    .master(sparkMaster) \
    .appName(sparkAppName) \
    .getOrCreate()

# %%
# Read all dataset
folder_path = 'D:\\00 Project\\00 My Project\\Dataset\\Revalue Nature\\Case 2\\' # Assuming this where all json file will be stored
file_name = '*.json' # Naming file convention
df_source = spark.read.json(folder_path + file_name, multiLine=True) # Read all json files
df_source.printSchema()
# Out:
# root
#  |-- alt: long (nullable = true)
#  |-- centre_ctrl: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- centre_id: long (nullable = true)
#  |    |    |-- start_time: string (nullable = true)
#  |-- centre_id: string (nullable = true)
#  |-- fpl: struct (nullable = true)
#  |    |-- fpl_arr: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- approach_clearance: boolean (nullable = true)
#  |    |    |    |-- arrival_runway: string (nullable = true)
#  |    |    |    |-- ata: string (nullable = true)
#  |    |    |    |-- missed_approach_flag: boolean (nullable = true)
#  |    |    |    |-- star: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |    |-- fpl_base: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- adar: string (nullable = true)
#  |    |    |    |-- adep: string (nullable = true)
#  |    |    |    |-- ades: string (nullable = true)
#  |    |    |    |-- aircraft_type: string (nullable = true)
#  |    |    |    |-- callsign: string (nullable = true)
#  |    |    |    |-- equip_status_rvsm: boolean (nullable = true)
#  |    |    |    |-- flight_rules: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |    |    |    |-- wtc: string (nullable = true)
#  |    |-- fpl_clearance: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- assign_heading_beacon: string (nullable = true)
#  |    |    |    |-- assigned_heading_val: double (nullable = true)
#  |    |    |    |-- assigned_speed_unit: string (nullable = true)
#  |    |    |    |-- assigned_speed_val: double (nullable = true)
#  |    |    |    |-- cfl: long (nullable = true)
#  |    |    |    |-- cfl_unit: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |    |-- fpl_dep: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- atd: string (nullable = true)
#  |    |    |    |-- departure_runway: string (nullable = true)
#  |    |    |    |-- iobt: string (nullable = true)
#  |    |    |    |-- sid: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |    |-- fpl_holding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- hold_stack_vol_name: string (nullable = true)
#  |    |    |    |-- holding_entry_time: string (nullable = true)
#  |    |    |    |-- holding_leaving_time: string (nullable = true)
#  |    |    |    |-- holding_stack_status: string (nullable = true)
#  |    |    |    |-- holding_status: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |    |-- fpl_plan_update: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- copn: string (nullable = true)
#  |    |    |    |-- copn_pel: long (nullable = true)
#  |    |    |    |-- copn_pel_unit: string (nullable = true)
#  |    |    |    |-- copx: string (nullable = true)
#  |    |    |    |-- copx_pel: long (nullable = true)
#  |    |    |    |-- copx_pel_unit: string (nullable = true)
#  |    |    |    |-- icao_route: string (nullable = true)
#  |    |    |    |-- rfl_string: string (nullable = true)
#  |    |    |    |-- tas_string: string (nullable = true)
#  |    |    |    |-- time_stamp: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- plots: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- I062/105: struct (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- lon: double (nullable = true)
#  |    |    |-- I062/136: struct (nullable = true)
#  |    |    |    |-- measured_flight_level: double (nullable = true)
#  |    |    |-- I062/185: struct (nullable = true)
#  |    |    |    |-- vx: double (nullable = true)
#  |    |    |    |-- vy: double (nullable = true)
#  |    |    |-- I062/200: struct (nullable = true)
#  |    |    |    |-- adf: boolean (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |    |    |    |-- trans: long (nullable = true)
#  |    |    |    |-- vert: long (nullable = true)
#  |    |    |-- I062/220: struct (nullable = true)
#  |    |    |    |-- rocd: double (nullable = true)
#  |    |    |-- I062/380: struct (nullable = true)
#  |    |    |    |-- subitem13: struct (nullable = true)
#  |    |    |    |    |-- baro_vert_rate: double (nullable = true)
#  |    |    |    |-- subitem26: struct (nullable = true)
#  |    |    |    |    |-- ias: long (nullable = true)
#  |    |    |    |-- subitem27: struct (nullable = true)
#  |    |    |    |    |-- mach: double (nullable = true)
#  |    |    |    |-- subitem3: struct (nullable = true)
#  |    |    |    |    |-- mag_hdg: double (nullable = true)
#  |    |    |    |-- subitem6: struct (nullable = true)
#  |    |    |    |    |-- altitude: long (nullable = true)
#  |    |    |    |    |-- sas: boolean (nullable = true)
#  |    |    |    |    |-- source: long (nullable = true)
#  |    |    |    |-- subitem7: struct (nullable = true)
#  |    |    |    |    |-- ah: boolean (nullable = true)
#  |    |    |    |    |-- altitude: long (nullable = true)
#  |    |    |    |    |-- am: boolean (nullable = true)
#  |    |    |    |    |-- mv: boolean (nullable = true)
#  |    |    |-- time_of_track: string (nullable = true)
#  |-- points: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lat: double (nullable = true)
#  |    |    |-- lon: double (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- predicted_trajectory: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- route: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- afl_unit: string (nullable = true)
#  |    |    |    |    |-- afl_value: double (nullable = true)
#  |    |    |    |    |-- eto: string (nullable = true)
#  |    |    |    |    |-- fix_kind: string (nullable = true)
#  |    |    |    |    |-- fix_name: string (nullable = true)
#  |    |    |    |    |-- is_ato: boolean (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |    |-- point_to_be_used_as_cop: boolean (nullable = true)
#  |    |    |    |    |-- rfl_unit: string (nullable = true)
#  |    |    |    |    |-- rfl_value: double (nullable = true)
#  |    |    |    |    |-- rule: string (nullable = true)
#  |    |    |-- time_stamp: string (nullable = true)
#  |-- sectors: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- volumes: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |    |-- max_alt: long (nullable = true)
#  |    |    |    |    |-- min_alt: long (nullable = true)
#  |-- temp: double (nullable = true)
#  |-- time: string (nullable = true)
#  |-- wind_dir: double (nullable = true)
#  |-- wind_spd: long (nullable = true)

# %% [markdown]
# ## Extract Data Function

# %%
def extract_data(df_source):
    # Extract important columns
    df_result1 = (df_source
                  .withColumn('id', col('id')) \
                  .withColumn('list_altitude', col('plots.I062/380.subitem7.altitude').cast(ArrayType(DoubleType())))
                  .withColumn('list_baro_vert_rate', col('plots.I062/380.subitem13.baro_vert_rate').cast(ArrayType(DoubleType())))
                  .withColumn('list_mach', col('plots.I062/380.subitem27.mach').cast(ArrayType(DoubleType())))
                  .withColumn('list_measured_flight_level', col('plots.I062/136.measured_flight_level').cast(ArrayType(DoubleType())))
                  .withColumn('list_start_time', col('centre_ctrl.start_time').cast(ArrayType(StringType())))
                  .withColumn('list_time_of_track', col('plots.time_of_track').cast(ArrayType(StringType())))
                  .withColumn('list_aircraft_type', col('fpl.fpl_base.aircraft_type'))
                  .withColumn('list_flight_rules', col('fpl.fpl_base.flight_rules'))
                )

    # Transform into new columns
    df_result2 = (df_result1
                  .withColumn("tmp", arrays_zip("list_altitude", "list_baro_vert_rate", "list_mach", "list_measured_flight_level", "list_time_of_track")) # ZIP array columns
                  .withColumn("tmp", explode("tmp")) # explode the array
                  .withColumn('plots_max_altitude', max(col("tmp.list_altitude")).over(Window.partitionBy('id'))) # get max altitude by id
                  .withColumn('plots_max_baro_vert_rate', max(col("tmp.list_baro_vert_rate")).over(Window.partitionBy('id'))) # get max baro_vert_rate by id
                  .withColumn('plots_max_mach', max(col("tmp.list_mach")).over(Window.partitionBy('id'))) # get max mach by id
                  .withColumn('plots_max_measured_flight_level', max(col("tmp.list_measured_flight_level")).over(Window.partitionBy('id'))) # get max measured_flight_level by id
                  .withColumn('end_time', max(to_timestamp(col("tmp.list_time_of_track"))).over(Window.partitionBy('id'))) # get end time
                  .withColumn("start_time", to_timestamp(df_result1["list_start_time"].getItem(0))) # get start time
                  .withColumn("duration_s", unix_timestamp("end_time") - unix_timestamp("start_time")) # get durations in second
                  .withColumn("duration_h", concat(expr("duration_s / 3600").cast(IntegerType()), lit("h")))
                  .withColumn("duration_m", concat(expr("(duration_s % 3600) / 60").cast(IntegerType()), lit("m")))
                  .withColumn("duration_s", concat(expr("duration_s % 60").cast(IntegerType()), lit("s")))
                  .withColumn("plots_duration", concat_ws(' ',col("duration_h"), col("duration_m"), col("duration_s"))) # get all durations
                  .withColumn('aircraft_type', df_result1["list_aircraft_type"].getItem(0)) # get aircraft type
                  .withColumn('flight_rules', df_result1["list_flight_rules"].getItem(0)) # get aircraft type
                 )
    
    df_result2 = df_result2.select('id', 'plots_duration', 'plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level', 'aircraft_type', 'flight_rules') \
                .distinct()
    return df_result2

df_test_input = spark.read.json(folder_path + '10000*.json', multiLine=True) # Read all json files
df_test_result = extract_data(df_test_input)
print(df_test_result.show())
# Out:
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
# |    id|plots_duration|plots_max_altitude|plots_max_baro_vert_rate|plots_max_mach|plots_max_measured_flight_level|aircraft_type|flight_rules|
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
# |100000|     0h 6m 26s|           33000.0|                  3325.0|         0.728|                          252.0|         B738|           I|
# |100001|     0h 32m 5s|           35000.0|                  381.25|         0.848|                          350.0|         B772|           I|
# |100002|     0h 47m 0s|           41000.0|                   162.5|         0.808|                          410.0|         B737|           I|
# |100003|    0h 49m 52s|           37800.0|                 3006.25|         0.792|                          340.0|         CRJ9|           I|
# |100004|    0h 18m 45s|           19000.0|                  993.75|         0.408|                          190.0|         AT76|           I|
# |100005|    0h 20m 34s|           34000.0|                  606.25|         0.848|                          340.0|         B772|           I|
# |100006|    0h 30m 33s|           40000.0|                 3293.75|         0.792|                          400.0|         B736|           I|
# |100007|    0h 51m 44s|              null|                 2206.25|          null|                          200.0|         AT45|           I|
# |100008|     0h 46m 6s|           37000.0|                 3106.25|           0.8|                          370.5|         A321|           I|
# |100009|    0h 50m 18s|           35000.0|                  4000.0|         0.792|                          350.0|         B738|           I|
# +------+--------------+------------------+------------------------+--------------+-------------------------------+-------------+------------+
#
# None

# %% [markdown]
# ## Prepare Final Result

# %%
def prepare_result_flights(df_source):
    # Select flights columns
    df_flights = df_source.select('id', 'plots_duration', 'plots_max_altitude', 'plots_max_baro_vert_rate', 'plots_max_mach', 'plots_max_measured_flight_level')
    # print(df_flights.show())
    
    # Convert to json format
    json_flights = df_flights.toJSON().collect()
    return json_flights

def prepare_result_aircraft_type(df_source):
    # Select unique_aircraft_type columns
    df_aircraft_type = df_source.select('aircraft_type')
    # print(df_aircraft_type.show())
    
    # Convert to json format
    list_unique_aircraft_type = df_aircraft_type.rdd.flatMap(lambda x: x).collect()
    return list_unique_aircraft_type

def prepare_result_flight_rules(df_source):
    # Select unique_flight_rules columns
    df_flight_rules = df_source.select('flight_rules')
    # print(df_flight_rules.show())
    
    # Convert to json format
    list_unique_flight_rules = df_flight_rules.rdd.flatMap(lambda x: x).collect()
    return list_unique_flight_rules

def build_dict(flights, aircraft_type, flight_rules):
    # Initialize Dictionary Result
    dict_result = {"flights": '', "unique_aircraft_type": '', "unique_flight_rules": ''}
    
    # Test dictionary
    dict_result["flights"] = flights
    dict_result["unique_aircraft_type"] = aircraft_type
    dict_result["unique_flight_rules"] = flight_rules

    return dict_result

# This is for testing purpose
df_flights = prepare_result_flights(df_test_result)
df_aircraft_type = prepare_result_aircraft_type(df_test_result)
df_flight_rules = prepare_result_flight_rules(df_test_result)
dict_result = build_dict(df_flights, df_aircraft_type, df_flight_rules)
pprint.pprint(dict_result)
# Out:
# {'flights': ['{"id":100000,"plots_duration":"0h 6m '
#              '26s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":3325.0,"plots_max_mach":0.728,"plots_max_measured_flight_level":252.0}',
#              '{"id":100001,"plots_duration":"0h 32m '
#              '5s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.848,"plots_max_measured_flight_level":350.0}',
#              '{"id":100002,"plots_duration":"0h 47m '
#              '0s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":410.0}',
#              '{"id":100003,"plots_duration":"0h 49m '
#              '52s","plots_max_altitude":37800.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":340.0}',
#              '{"id":100004,"plots_duration":"0h 18m '
#              '45s","plots_max_altitude":19000.0,"plots_max_baro_vert_rate":993.75,"plots_max_mach":0.408,"plots_max_measured_flight_level":190.0}',
#              '{"id":100005,"plots_duration":"0h 20m '
#              '34s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.848,"plots_max_measured_flight_level":340.0}',
#              '{"id":100006,"plots_duration":"0h 30m '
#              '33s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":3293.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0}',
#              '{"id":100007,"plots_duration":"0h 51m '
#              '44s","plots_max_baro_vert_rate":2206.25,"plots_max_measured_flight_level":200.0}',
#              '{"id":100008,"plots_duration":"0h 46m '
#              '6s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3106.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.5}',
#              '{"id":100009,"plots_duration":"0h 50m '
#              '18s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4000.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":350.0}'],
#  'unique_aircraft_type': ['B738',
#                           'B772',
#                           'B737',
#                           'CRJ9',
#                           'AT76',
#                           'B772',
#                           'B736',
#                           'AT45',
#                           'A321',
#                           'B738'],
#  'unique_flight_rules': ['I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I']}

# %% [markdown]
# ## Extract and Transforms All Data

# %%
df_extraction = extract_data(df_source)
print("Total Data: ",df_extraction.count())
# Out:
# Total Data:  13138

# %%
df_flights = prepare_result_flights(df_extraction)
print("Done Preparing Flights Table")
# Out:
# Done Preparing Flights Table

# %%
df_aircraft_type = prepare_result_aircraft_type(df_extraction)
print("Done Preparing Aircraft Type Table")
# Out:
# Done Preparing Aircraft Type Table

# %%
df_flight_rules = prepare_result_flight_rules(df_extraction)
print("Done Preparing Flight Rules Table")
# Out:
# Done Preparing Flight Rules Table

# %%
dict_result = build_dict(df_flights, df_aircraft_type, df_flight_rules)
print("Done Preparing Final Dictionary")
# Out:
# Done Preparing Final Dictionary

# %%
pprint.pprint(dict_result)
# Out:
# {'flights': ['{"id":100012,"plots_duration":"0h 49m '
#              '47s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":100016,"plots_duration":"0h 44m '
#              '44s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":100017,"plots_duration":"1h 2m '
#              '5s","plots_max_altitude":16000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.44,"plots_max_measured_flight_level":160.25}',
#              '{"id":100030,"plots_duration":"1h 6m '
#              '19s","plots_max_baro_vert_rate":1981.25,"plots_max_mach":0.504,"plots_max_measured_flight_level":190.0}',
#              '{"id":100031,"plots_duration":"0h 16m '
#              '59s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.856,"plots_max_measured_flight_level":340.0}',
#              '{"id":100034,"plots_duration":"0h 35m '
#              '58s","plots_max_measured_flight_level":200.0}',
#              '{"id":100039,"plots_duration":"0h 43m '
#              '31s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":410.25}',
#              '{"id":100040,"plots_duration":"0h 17m '
#              '8s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":3837.5,"plots_max_mach":0.728,"plots_max_measured_flight_level":245.25}',
#              '{"id":100041,"plots_duration":"0h 41m '
#              '4s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.488,"plots_max_measured_flight_level":170.0}',
#              '{"id":100047,"plots_duration":"0h 52m '
#              '16s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":361.0}',
#              '{"id":100052,"plots_duration":"0h 34m '
#              '55s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":1918.75,"plots_max_mach":0.84,"plots_max_measured_flight_level":330.0}',
#              '{"id":100064,"plots_duration":"0h 48m '
#              '28s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":6081.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":100068,"plots_duration":"0h 35m '
#              '11s","plots_max_altitude":18000.0,"plots_max_baro_vert_rate":2562.5,"plots_max_mach":0.472,"plots_max_measured_flight_level":140.5}',
#              '{"id":100075,"plots_duration":"0h 58m '
#              '33s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":2818.75,"plots_max_mach":0.688,"plots_max_measured_flight_level":310.25}',
#              '{"id":100077,"plots_duration":"0h 16m '
#              '21s","plots_max_baro_vert_rate":1312.5,"plots_max_measured_flight_level":110.25}',
#              '{"id":100079,"plots_duration":"1h 7m '
#              '10s","plots_max_measured_flight_level":180.0}',
#              '{"id":100082,"plots_duration":"0h 27m '
#              '1s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3581.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.0}',
#              '{"id":100083,"plots_duration":"0h 42m '
#              '21s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":3618.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":410.0}',
#              '{"id":100085,"plots_duration":"0h 58m '
#              '10s","plots_max_altitude":30000.0,"plots_max_baro_vert_rate":3293.75,"plots_max_mach":0.688,"plots_max_measured_flight_level":300.0}',
#              '{"id":100087,"plots_duration":"0h 23m '
#              '55s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":0.0,"plots_max_mach":0.832,"plots_max_measured_flight_level":320.25}',
#              '{"id":100089,"plots_duration":"0h 44m '
#              '23s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.5}',
#              '{"id":100090,"plots_duration":"0h 22m '
#              '14s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":93.75,"plots_max_mach":0.584,"plots_max_measured_flight_level":176.25}',
#              '{"id":100106,"plots_duration":"0h 41m '
#              '10s","plots_max_altitude":50000.0,"plots_max_baro_vert_rate":3968.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":380.0}',
#              '{"id":100108,"plots_duration":"0h 48m '
#              '10s","plots_max_altitude":18000.0,"plots_max_baro_vert_rate":1825.0,"plots_max_mach":0.488,"plots_max_measured_flight_level":180.0}',
#              '{"id":100109,"plots_duration":"0h 45m '
#              '39s","plots_max_altitude":41500.0,"plots_max_baro_vert_rate":4800.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":410.0}',
#              '{"id":100113,"plots_duration":"0h 37m '
#              '56s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":575.0,"plots_max_mach":0.808,"plots_max_measured_flight_level":340.0}',
#              '{"id":100118,"plots_duration":"0h 45m '
#              '37s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":410.0}',
#              '{"id":100121,"plots_duration":"0h 53m '
#              '34s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":100124,"plots_duration":"0h 4m '
#              '8s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":2850.0,"plots_max_mach":0.664,"plots_max_measured_flight_level":234.0}',
#              '{"id":100130,"plots_duration":"1h 0m '
#              '14s","plots_max_measured_flight_level":161.0}',
#              '{"id":100132,"plots_duration":"0h 55m '
#              '43s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":100133,"plots_duration":"0h 45m '
#              '9s","plots_max_altitude":41850.0,"plots_max_baro_vert_rate":1312.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":100139,"plots_duration":"0h 24m '
#              '26s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.472,"plots_max_measured_flight_level":153.5}',
#              '{"id":100147,"plots_duration":"0h 44m '
#              '22s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4350.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":381.0}',
#              '{"id":100157,"plots_duration":"0h 24m '
#              '41s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3200.0,"plots_max_mach":0.808,"plots_max_measured_flight_level":360.0}',
#              '{"id":100163,"plots_duration":"0h 31m '
#              '49s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.776,"plots_max_measured_flight_level":380.0}',
#              '{"id":100170,"plots_duration":"0h 46m '
#              '2s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.5}',
#              '{"id":100177,"plots_duration":"0h 59m '
#              '43s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.768,"plots_max_measured_flight_level":380.0}',
#              '{"id":100188,"plots_duration":"0h 44m '
#              '56s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":675.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.5}',
#              '{"id":100189,"plots_duration":"0h 8m '
#              '15s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3937.5,"plots_max_mach":0.72,"plots_max_measured_flight_level":266.0}',
#              '{"id":100192,"plots_duration":"0h 33m '
#              '1s","plots_max_measured_flight_level":160.0}',
#              '{"id":100194,"plots_duration":"0h 52m '
#              '6s","plots_max_measured_flight_level":170.25}',
#              '{"id":100202,"plots_duration":"0h 16m '
#              '15s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":-2462.5,"plots_max_mach":0.696,"plots_max_measured_flight_level":214.25}',
#              '{"id":100214,"plots_duration":"0h 49m '
#              '43s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":381.0}',
#              '{"id":100217,"plots_duration":"0h 53m '
#              '26s","plots_max_altitude":15000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.472,"plots_max_measured_flight_level":150.0}',
#              '{"id":100223,"plots_duration":"0h 43m '
#              '32s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4993.75,"plots_max_mach":0.768,"plots_max_measured_flight_level":390.0}',
#              '{"id":100229,"plots_duration":"0h 24m '
#              '49s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.0}',
#              '{"id":100230,"plots_duration":"0h 41m '
#              '56s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":4737.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":340.0}',
#              '{"id":100238,"plots_duration":"0h 54m '
#              '39s","plots_max_altitude":26000.0,"plots_max_baro_vert_rate":2912.5,"plots_max_mach":0.616,"plots_max_measured_flight_level":260.25}',
#              '{"id":100256,"plots_duration":"0h 47m '
#              '28s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.25}',
#              '{"id":100258,"plots_duration":"0h 46m '
#              '22s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0}',
#              '{"id":100269,"plots_duration":"1h 6m '
#              '41s","plots_max_measured_flight_level":410.0}',
#              '{"id":100274,"plots_duration":"0h 24m '
#              '37s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":2818.75,"plots_max_mach":0.752,"plots_max_measured_flight_level":360.0}',
#              '{"id":100281,"plots_duration":"0h 25m '
#              '49s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3168.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.25}',
#              '{"id":100284,"plots_duration":"0h 33m '
#              '15s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":100299,"plots_duration":"0h 17m '
#              '34s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":31.25,"plots_max_mach":0.632,"plots_max_measured_flight_level":204.75}',
#              '{"id":100302,"plots_duration":"0h 45m '
#              '2s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":4543.75,"plots_max_mach":0.76,"plots_max_measured_flight_level":340.0}',
#              '{"id":100303,"plots_duration":"1h 8m '
#              '4s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":5118.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":100305,"plots_duration":"0h 37m '
#              '29s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":1537.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.0}',
#              '{"id":100316,"plots_duration":"0h 33m '
#              '29s","plots_max_altitude":18000.0,"plots_max_baro_vert_rate":768.75,"plots_max_mach":0.432,"plots_max_measured_flight_level":180.25}',
#              '{"id":100317,"plots_duration":"0h 52m '
#              '46s","plots_max_measured_flight_level":180.0}',
#              '{"id":100321,"plots_duration":"0h 49m '
#              '11s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":125.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":390.0}',
#              '{"id":100323,"plots_duration":"0h 8m '
#              '29s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":3075.0,"plots_max_mach":0.68,"plots_max_measured_flight_level":237.0}',
#              '{"id":100330,"plots_duration":"0h 14m '
#              '59s","plots_max_baro_vert_rate":350.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.0}',
#              '{"id":100347,"plots_duration":"0h 24m '
#              '13s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":320.0}',
#              '{"id":100358,"plots_duration":"0h 51m '
#              '57s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":350.0}',
#              '{"id":100365,"plots_duration":"0h 52m '
#              '21s","plots_max_altitude":15000.0,"plots_max_baro_vert_rate":1825.0,"plots_max_mach":0.48,"plots_max_measured_flight_level":150.0}',
#              '{"id":100366,"plots_duration":"0h 38m '
#              '21s","plots_max_altitude":39250.0,"plots_max_baro_vert_rate":3775.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.25}',
#              '{"id":100373,"plots_duration":"0h 50m '
#              '14s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":2850.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.0}',
#              '{"id":100376,"plots_duration":"0h 47m '
#              '41s","plots_max_altitude":21000.0,"plots_max_baro_vert_rate":1506.25,"plots_max_mach":0.512,"plots_max_measured_flight_level":210.0}',
#              '{"id":100398,"plots_duration":"0h 32m '
#              '8s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.752,"plots_max_measured_flight_level":360.25}',
#              '{"id":100409,"plots_duration":"0h 16m '
#              '11s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4062.5,"plots_max_mach":0.776,"plots_max_measured_flight_level":343.0}',
#              '{"id":100414,"plots_duration":"0h 48m '
#              '31s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":3743.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":100435,"plots_duration":"0h 14m '
#              '22s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":-350.0,"plots_max_mach":0.76,"plots_max_measured_flight_level":330.0}',
#              '{"id":100436,"plots_duration":"0h 59m '
#              '49s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4481.25,"plots_max_mach":0.744,"plots_max_measured_flight_level":360.0}',
#              '{"id":100437,"plots_duration":"1h 8m '
#              '23s","plots_max_baro_vert_rate":2018.75,"plots_max_mach":0.496,"plots_max_measured_flight_level":190.25}',
#              '{"id":100438,"plots_duration":"0h 8m '
#              '27s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3775.0,"plots_max_mach":0.68,"plots_max_measured_flight_level":256.0}',
#              '{"id":100440,"plots_duration":"0h 40m '
#              '39s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":706.25,"plots_max_mach":0.824,"plots_max_measured_flight_level":380.0}',
#              '{"id":100444,"plots_duration":"0h 44m '
#              '52s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":410.0}',
#              '{"id":100448,"plots_duration":"0h 58m '
#              '18s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4318.75,"plots_max_mach":0.744,"plots_max_measured_flight_level":350.0}',
#              '{"id":100465,"plots_duration":"0h 53m '
#              '59s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4737.5,"plots_max_mach":0.816,"plots_max_measured_flight_level":330.0}',
#              '{"id":100470,"plots_duration":"0h 15m '
#              '36s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.768,"plots_max_measured_flight_level":350.25}',
#              '{"id":100472,"plots_duration":"0h 30m '
#              '56s","plots_max_altitude":18000.0,"plots_max_baro_vert_rate":1662.5,"plots_max_mach":0.44,"plots_max_measured_flight_level":180.0}',
#              '{"id":100473,"plots_duration":"0h 46m '
#              '34s","plots_max_altitude":18000.0,"plots_max_baro_vert_rate":2143.75,"plots_max_mach":0.496,"plots_max_measured_flight_level":180.0}',
#              '{"id":100474,"plots_duration":"0h 46m '
#              '49s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4706.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":381.0}',
#              '{"id":100492,"plots_duration":"0h 51m '
#              '17s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3137.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":350.0}',
#              '{"id":100497,"plots_duration":"1h 11m '
#              '17s","plots_max_altitude":65450.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.896,"plots_max_measured_flight_level":380.0}',
#              '{"id":100501,"plots_duration":"0h 45m '
#              '26s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":2275.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":370.25}',
#              '{"id":100502,"plots_duration":"0h 59m '
#              '2s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":1406.25,"plots_max_mach":0.704,"plots_max_measured_flight_level":310.25}',
#              '{"id":100504,"plots_duration":"0h 22m '
#              '8s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.512,"plots_max_measured_flight_level":192.0}',
#              '{"id":100515,"plots_duration":"0h 35m '
#              '58s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4000.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0}',
#              '{"id":100527,"plots_duration":"0h 56m '
#              '1s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4350.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":350.0}',
#              '{"id":100528,"plots_duration":"1h 2m '
#              '26s","plots_max_altitude":31200.0,"plots_max_baro_vert_rate":2912.5,"plots_max_mach":0.712,"plots_max_measured_flight_level":310.25}',
#              '{"id":100531,"plots_duration":"0h 46m '
#              '25s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.0}',
#              '{"id":100534,"plots_duration":"0h 49m '
#              '11s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.816,"plots_max_measured_flight_level":370.0}',
#              '{"id":100536,"plots_duration":"0h 16m '
#              '20s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4481.25,"plots_max_mach":0.768,"plots_max_measured_flight_level":309.25}',
#              '{"id":100539,"plots_duration":"0h 7m '
#              '8s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4256.25,"plots_max_mach":0.72,"plots_max_measured_flight_level":225.0}',
#              '{"id":100548,"plots_duration":"0h 35m '
#              '18s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":360.0}',
#              '{"id":100552,"plots_duration":"0h 42m '
#              '5s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4093.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":381.0}',
#              '{"id":100561,"plots_duration":"0h 24m '
#              '20s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0}',
#              '{"id":100565,"plots_duration":"0h 26m '
#              '19s","plots_max_altitude":15000.0,"plots_max_baro_vert_rate":4800.0,"plots_max_mach":0.64,"plots_max_measured_flight_level":150.0}',
#              '{"id":100572,"plots_duration":"0h 50m '
#              '53s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":3968.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":340.0}',
#              '{"id":100586,"plots_duration":"0h 32m '
#              '43s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":350.0}',
#              '{"id":100596,"plots_duration":"0h 30m '
#              '40s","plots_max_altitude":24000.0,"plots_max_baro_vert_rate":125.0,"plots_max_mach":0.584,"plots_max_measured_flight_level":240.25}',
#              '{"id":100616,"plots_duration":"1h 2m '
#              '35s","plots_max_altitude":18100.0,"plots_max_baro_vert_rate":2275.0,"plots_max_mach":0.488,"plots_max_measured_flight_level":180.25}',
#              '{"id":100628,"plots_duration":"0h 38m '
#              '58s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":1087.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":400.0}',
#              '{"id":100638,"plots_duration":"0h 29m '
#              '43s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":675.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.5}',
#              '{"id":100645,"plots_duration":"0h 27m '
#              '40s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":100646,"plots_duration":"1h 0m '
#              '23s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4318.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":390.0}',
#              '{"id":100649,"plots_duration":"0h 54m '
#              '20s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":2975.0,"plots_max_mach":0.704,"plots_max_measured_flight_level":320.5}',
#              '{"id":100652,"plots_duration":"0h 56m '
#              '10s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.25}',
#              '{"id":100670,"plots_duration":"0h 50m '
#              '44s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":925.0,"plots_max_mach":0.752,"plots_max_measured_flight_level":340.25}',
#              '{"id":100673,"plots_duration":"0h 45m '
#              '29s","plots_max_altitude":26000.0,"plots_max_baro_vert_rate":2625.0,"plots_max_mach":0.624,"plots_max_measured_flight_level":260.25}',
#              '{"id":100674,"plots_duration":"0h 32m '
#              '22s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":2750.0,"plots_max_mach":0.768,"plots_max_measured_flight_level":390.0}',
#              '{"id":100676,"plots_duration":"0h 36m '
#              '53s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4381.25,"plots_max_mach":0.808,"plots_max_measured_flight_level":401.0}',
#              '{"id":100687,"plots_duration":"0h 44m '
#              '54s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.808,"plots_max_measured_flight_level":370.25}',
#              '{"id":100690,"plots_duration":"0h 42m '
#              '53s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":737.5,"plots_max_mach":0.84,"plots_max_measured_flight_level":360.0}',
#              '{"id":100693,"plots_duration":"0h 23m '
#              '43s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":62.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":100695,"plots_duration":"0h 35m '
#              '16s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3231.25,"plots_max_mach":0.72,"plots_max_measured_flight_level":350.0}',
#              '{"id":100704,"plots_duration":"0h 33m '
#              '58s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":800.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":400.0}',
#              '{"id":100711,"plots_duration":"0h 46m '
#              '43s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.928,"plots_max_measured_flight_level":310.0}',
#              '{"id":100716,"plots_duration":"0h 54m '
#              '10s","plots_max_altitude":27000.0,"plots_max_baro_vert_rate":2718.75,"plots_max_mach":0.64,"plots_max_measured_flight_level":270.25}',
#              '{"id":100721,"plots_duration":"0h 41m '
#              '14s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4575.0,"plots_max_mach":0.776,"plots_max_measured_flight_level":330.25}',
#              '{"id":100723,"plots_duration":"0h 38m '
#              '50s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0}',
#              '{"id":100726,"plots_duration":"0h 52m '
#              '4s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":831.25,"plots_max_mach":0.704,"plots_max_measured_flight_level":310.25}',
#              '{"id":100730,"plots_duration":"0h 8m '
#              '35s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":5025.0,"plots_max_mach":0.672,"plots_max_measured_flight_level":264.25}',
#              '{"id":100731,"plots_duration":"0h 48m '
#              '29s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":371.0}',
#              '{"id":100737,"plots_duration":"0h 44m '
#              '5s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.768,"plots_max_measured_flight_level":340.0}',
#              '{"id":100756,"plots_duration":"0h 47m '
#              '59s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":100761,"plots_duration":"0h 16m '
#              '48s","plots_max_altitude":5000.0,"plots_max_baro_vert_rate":-31.25,"plots_max_mach":0.472,"plots_max_measured_flight_level":101.0}',
#              '{"id":100763,"plots_duration":"0h 39m '
#              '41s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":2050.0,"plots_max_mach":0.768,"plots_max_measured_flight_level":330.25}',
#              '{"id":100766,"plots_duration":"0h 40m '
#              '35s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4381.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.0}',
#              '{"id":100768,"plots_duration":"0h 44m '
#              '31s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3806.25,"plots_max_mach":0.776,"plots_max_measured_flight_level":390.25}',
#              '{"id":100770,"plots_duration":"0h 49m '
#              '49s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":1056.25,"plots_max_mach":0.736,"plots_max_measured_flight_level":340.0}',
#              '{"id":100773,"plots_duration":"0h 27m '
#              '33s","plots_max_measured_flight_level":350.0}',
#              '{"id":100778,"plots_duration":"0h 57m '
#              '42s","plots_max_altitude":23000.0,"plots_max_baro_vert_rate":768.75,"plots_max_mach":0.536,"plots_max_measured_flight_level":230.0}',
#              '{"id":100784,"plots_duration":"1h 5m '
#              '8s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":340.0}',
#              '{"id":100789,"plots_duration":"0h 58m '
#              '9s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":100794,"plots_duration":"0h 41m '
#              '39s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":3650.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.25}',
#              '{"id":100796,"plots_duration":"0h 46m '
#              '35s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3618.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":351.0}',
#              '{"id":100821,"plots_duration":"0h 59m '
#              '51s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4418.75,"plots_max_mach":0.744,"plots_max_measured_flight_level":370.0}',
#              '{"id":100822,"plots_duration":"0h 40m '
#              '11s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":340.0}',
#              '{"id":100823,"plots_duration":"0h 27m '
#              '23s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":2781.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.5}',
#              '{"id":100826,"plots_duration":"0h 44m '
#              '34s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4193.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":391.0}',
#              '{"id":100832,"plots_duration":"0h 36m '
#              '36s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":370.0}',
#              '{"id":100834,"plots_duration":"0h 49m '
#              '56s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":862.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":381.0}',
#              '{"id":100840,"plots_duration":"0h 41m '
#              '58s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3775.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":391.0}',
#              '{"id":100847,"plots_duration":"0h 52m '
#              '50s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":125.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.25}',
#              '{"id":100852,"plots_duration":"0h 49m '
#              '45s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":390.0}',
#              '{"id":100857,"plots_duration":"0h 44m '
#              '33s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":390.5}',
#              '{"id":100869,"plots_duration":"0h 40m '
#              '38s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4093.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":100870,"plots_duration":"0h 46m '
#              '13s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.0}',
#              '{"id":100873,"plots_duration":"0h 47m '
#              '33s","plots_max_altitude":27000.0,"plots_max_baro_vert_rate":10237.5,"plots_max_mach":0.68,"plots_max_measured_flight_level":270.25}',
#              '{"id":100903,"plots_duration":"0h 43m '
#              '49s","plots_max_measured_flight_level":131.0}',
#              '{"id":100904,"plots_duration":"0h 59m '
#              '46s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4093.75,"plots_max_mach":0.76,"plots_max_measured_flight_level":350.0}',
#              '{"id":100910,"plots_duration":"0h 21m '
#              '19s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":637.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":370.0}',
#              '{"id":100915,"plots_duration":"0h 50m '
#              '59s","plots_max_baro_vert_rate":3325.0,"plots_max_mach":0.624,"plots_max_measured_flight_level":260.25}',
#              '{"id":100921,"plots_duration":"0h 39m '
#              '20s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":925.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":340.25}',
#              '{"id":100926,"plots_duration":"0h 29m '
#              '17s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":93.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":360.0}',
#              '{"id":100928,"plots_duration":"0h 29m '
#              '48s","plots_max_altitude":19000.0,"plots_max_baro_vert_rate":2625.0,"plots_max_mach":0.656,"plots_max_measured_flight_level":190.25}',
#              '{"id":100938,"plots_duration":"0h 38m '
#              '43s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":3837.5,"plots_max_mach":0.704,"plots_max_measured_flight_level":310.0}',
#              '{"id":100943,"plots_duration":"0h 43m '
#              '30s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4893.75,"plots_max_mach":0.76,"plots_max_measured_flight_level":340.0}',
#              '{"id":100952,"plots_duration":"0h 44m '
#              '13s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":125.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":350.5}',
#              '{"id":100958,"plots_duration":"0h 28m '
#              '31s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.768,"plots_max_measured_flight_level":380.0}',
#              '{"id":100961,"plots_duration":"0h 43m '
#              '13s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4706.25,"plots_max_mach":0.776,"plots_max_measured_flight_level":401.0}',
#              '{"id":100966,"plots_duration":"0h 57m '
#              '42s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":2818.75,"plots_max_mach":0.624,"plots_max_measured_flight_level":280.25}',
#              '{"id":100986,"plots_duration":"0h 41m '
#              '34s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4318.75,"plots_max_mach":0.864,"plots_max_measured_flight_level":370.25}',
#              '{"id":100987,"plots_duration":"0h 41m '
#              '3s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":2050.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.0}',
#              '{"id":100988,"plots_duration":"0h 47m '
#              '15s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.808,"plots_max_measured_flight_level":340.0}',
#              '{"id":100992,"plots_duration":"1h 0m '
#              '5s","plots_max_altitude":27000.0,"plots_max_baro_vert_rate":2975.0,"plots_max_mach":0.624,"plots_max_measured_flight_level":270.25}',
#              '{"id":100996,"plots_duration":"0h 26m '
#              '54s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":575.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":101011,"plots_duration":"0h 25m '
#              '26s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4350.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":101013,"plots_duration":"0h 32m '
#              '55s","plots_max_altitude":27000.0,"plots_max_baro_vert_rate":4318.75,"plots_max_mach":0.768,"plots_max_measured_flight_level":270.0}',
#              '{"id":101019,"plots_duration":"0h 43m '
#              '11s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":360.0}',
#              '{"id":101020,"plots_duration":"0h 33m '
#              '2s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":925.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":290.0}',
#              '{"id":101031,"plots_duration":"0h 24m '
#              '30s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":349.25}',
#              '{"id":101032,"plots_duration":"0h 5m '
#              '33s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":3262.5,"plots_max_mach":0.696,"plots_max_measured_flight_level":248.75}',
#              '{"id":101033,"plots_duration":"0h 14m '
#              '55s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3137.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":318.0}',
#              '{"id":101064,"plots_duration":"0h 53m '
#              '5s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.25}',
#              '{"id":101066,"plots_duration":"0h 47m '
#              '19s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.25}',
#              '{"id":101067,"plots_duration":"0h 57m '
#              '54s","plots_max_altitude":20000.0,"plots_max_baro_vert_rate":1218.75,"plots_max_mach":0.472,"plots_max_measured_flight_level":160.25}',
#              '{"id":101071,"plots_duration":"0h 21m '
#              '55s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.584,"plots_max_measured_flight_level":214.5}',
#              '{"id":101083,"plots_duration":"0h 44m '
#              '22s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":2975.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":350.0}',
#              '{"id":101091,"plots_duration":"0h 37m '
#              '22s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":370.0}',
#              '{"id":101092,"plots_duration":"0h 19m '
#              '32s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":-637.5,"plots_max_mach":0.784,"plots_max_measured_flight_level":363.75}',
#              '{"id":101093,"plots_duration":"0h 23m '
#              '33s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.752,"plots_max_measured_flight_level":350.0}',
#              '{"id":101100,"plots_duration":"0h 20m '
#              '38s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":-706.25,"plots_max_mach":0.744,"plots_max_measured_flight_level":369.75}',
#              '{"id":101101,"plots_duration":"0h 33m '
#              '47s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.84,"plots_max_measured_flight_level":380.0}',
#              '{"id":101115,"plots_duration":"0h 49m '
#              '18s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.25}',
#              '{"id":101116,"plots_duration":"0h 44m '
#              '31s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":101121,"plots_duration":"0h 49m '
#              '33s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3650.0,"plots_max_mach":0.744,"plots_max_measured_flight_level":350.0}',
#              '{"id":101127,"plots_duration":"0h 57m '
#              '38s","plots_max_altitude":14000.0,"plots_max_baro_vert_rate":1793.75,"plots_max_mach":0.416,"plots_max_measured_flight_level":140.0}',
#              '{"id":101135,"plots_duration":"0h 36m '
#              '49s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.84,"plots_max_measured_flight_level":340.0}',
#              '{"id":101136,"plots_duration":"0h 43m '
#              '13s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3393.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":370.0}',
#              '{"id":101143,"plots_duration":"0h 38m '
#              '27s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4418.75,"plots_max_mach":0.808,"plots_max_measured_flight_level":400.0}',
#              '{"id":101152,"plots_duration":"1h 10m '
#              '28s","plots_max_measured_flight_level":160.0}',
#              '{"id":101155,"plots_duration":"0h 44m '
#              '26s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3106.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":390.25}',
#              '{"id":101160,"plots_duration":"0h 44m '
#              '9s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.768,"plots_max_measured_flight_level":360.0}',
#              '{"id":101163,"plots_duration":"0h 12m '
#              '47s","plots_max_altitude":31200.0,"plots_max_baro_vert_rate":3650.0,"plots_max_mach":0.64,"plots_max_measured_flight_level":225.25}',
#              '{"id":101166,"plots_duration":"0h 39m '
#              '15s","plots_max_altitude":37200.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":101171,"plots_duration":"0h 38m '
#              '2s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0}',
#              '{"id":101174,"plots_duration":"0h 21m '
#              '7s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3456.25,"plots_max_mach":0.784,"plots_max_measured_flight_level":350.0}',
#              '{"id":101188,"plots_duration":"1h 1m '
#              '58s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3650.0,"plots_max_mach":0.792,"plots_max_measured_flight_level":350.0}',
#              '{"id":101190,"plots_duration":"0h 16m '
#              '5s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.736,"plots_max_measured_flight_level":320.25}',
#              '{"id":101191,"plots_duration":"0h 36m '
#              '7s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3168.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.0}',
#              '{"id":101199,"plots_duration":"0h 42m '
#              '41s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4062.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":101200,"plots_duration":"0h 35m '
#              '44s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":62.5,"plots_max_mach":0.448,"plots_max_measured_flight_level":170.0}',
#              '{"id":101203,"plots_duration":"0h 13m '
#              '49s","plots_max_measured_flight_level":110.0}',
#              '{"id":101208,"plots_duration":"0h 48m '
#              '9s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":3806.25,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":101218,"plots_duration":"0h 44m '
#              '12s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.816,"plots_max_measured_flight_level":380.0}',
#              '{"id":101221,"plots_duration":"0h 28m '
#              '32s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":5856.25,"plots_max_mach":0.736,"plots_max_measured_flight_level":340.0}',
#              '{"id":101225,"plots_duration":"0h 40m '
#              '24s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4031.25,"plots_max_mach":0.808,"plots_max_measured_flight_level":360.25}',
#              '{"id":101229,"plots_duration":"0h 40m '
#              '37s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":606.25,"plots_max_mach":0.808,"plots_max_measured_flight_level":380.0}',
#              '{"id":101231,"plots_duration":"0h 58m '
#              '13s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":101232,"plots_duration":"0h 39m '
#              '56s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3743.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0}',
#              '{"id":101240,"plots_duration":"0h 39m '
#              '6s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4768.75,"plots_max_mach":0.816,"plots_max_measured_flight_level":360.25}',
#              '{"id":101251,"plots_duration":"0h 50m '
#              '55s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":3743.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":101256,"plots_duration":"0h 54m '
#              '32s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":3681.25,"plots_max_mach":0.776,"plots_max_measured_flight_level":390.0}',
#              '{"id":101263,"plots_duration":"0h 36m '
#              '11s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":1150.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":370.25}',
#              '{"id":101266,"plots_duration":"1h 3m '
#              '8s","plots_max_measured_flight_level":161.0}',
#              '{"id":101267,"plots_duration":"1h 9m '
#              '20s","plots_max_baro_vert_rate":1981.25,"plots_max_mach":0.488,"plots_max_measured_flight_level":170.0}',
#              '{"id":101273,"plots_duration":"0h 12m '
#              '42s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3906.25,"plots_max_mach":0.6,"plots_max_measured_flight_level":177.0}',
#              '{"id":101284,"plots_duration":"0h 14m '
#              '42s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.856,"plots_max_measured_flight_level":340.0}',
#              '{"id":101286,"plots_duration":"0h 46m '
#              '4s","plots_max_altitude":34650.0,"plots_max_baro_vert_rate":4287.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":340.25}',
#              '{"id":101296,"plots_duration":"0h 32m '
#              '40s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":1825.0,"plots_max_mach":0.84,"plots_max_measured_flight_level":310.0}',
#              '{"id":101307,"plots_duration":"0h 16m '
#              '5s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.856,"plots_max_measured_flight_level":380.0}',
#              '{"id":101309,"plots_duration":"0h 52m '
#              '47s","plots_max_measured_flight_level":180.0}',
#              '{"id":101318,"plots_duration":"0h 20m '
#              '50s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":-737.5,"plots_max_mach":0.576,"plots_max_measured_flight_level":157.5}',
#              '{"id":101322,"plots_duration":"0h 36m '
#              '55s","plots_max_altitude":65525.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.848,"plots_max_measured_flight_level":320.0}',
#              '{"id":101325,"plots_duration":"0h 47m '
#              '47s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":4287.5,"plots_max_mach":0.8,"plots_max_measured_flight_level":400.0}',
#              '{"id":101327,"plots_duration":"0h 34m '
#              '19s","plots_max_measured_flight_level":180.0}',
#              '{"id":101328,"plots_duration":"0h 45m '
#              '44s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":1150.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":320.5}',
#              '{"id":101333,"plots_duration":"1h 3m '
#              '32s","plots_max_altitude":16000.0,"plots_max_baro_vert_rate":2493.75,"plots_max_mach":0.464,"plots_max_measured_flight_level":140.25}',
#              '{"id":101341,"plots_duration":"0h 31m '
#              '35s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":2462.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":380.25}',
#              '{"id":101358,"plots_duration":"0h 50m '
#              '6s","plots_max_baro_vert_rate":2368.75,"plots_max_measured_flight_level":180.0}',
#              '{"id":101361,"plots_duration":"0h 40m '
#              '8s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":3581.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":340.0}',
#              '{"id":101368,"plots_duration":"0h 43m '
#              '7s","plots_max_altitude":41325.0,"plots_max_baro_vert_rate":4737.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":360.0}',
#              '{"id":101384,"plots_duration":"0h 35m '
#              '44s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":3906.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":101397,"plots_duration":"0h 51m '
#              '34s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":512.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":410.25}',
#              '{"id":101414,"plots_duration":"1h 3m '
#              '3s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":1662.5,"plots_max_mach":0.424,"plots_max_measured_flight_level":170.25}',
#              '{"id":101419,"plots_duration":"0h 22m '
#              '47s","plots_max_altitude":16000.0,"plots_max_baro_vert_rate":-1181.25,"plots_max_mach":0.696,"plots_max_measured_flight_level":244.0}',
#              '{"id":101420,"plots_duration":"0h 20m '
#              '34s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.84,"plots_max_measured_flight_level":340.0}',
#              '{"id":101429,"plots_duration":"0h 33m '
#              '31s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4093.75,"plots_max_mach":0.84,"plots_max_measured_flight_level":360.0}',
#              '{"id":101435,"plots_duration":"0h 32m '
#              '16s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.864,"plots_max_measured_flight_level":330.0}',
#              '{"id":101437,"plots_duration":"0h 39m '
#              '33s","plots_max_altitude":24000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.56,"plots_max_measured_flight_level":240.0}',
# ...
#              '57s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":1793.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":109252,"plots_duration":"0h 48m '
#              '11s","plots_max_measured_flight_level":131.0}',
#              '{"id":109269,"plots_duration":"0h 21m '
#              '59s","plots_max_altitude":22000.0,"plots_max_baro_vert_rate":2850.0,"plots_max_mach":0.568,"plots_max_measured_flight_level":220.25}',
#              '{"id":109321,"plots_duration":"0h 39m '
#              '28s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":109366,"plots_duration":"0h 48m '
#              '1s","plots_max_altitude":22000.0,"plots_max_baro_vert_rate":3712.5,"plots_max_mach":0.584,"plots_max_measured_flight_level":220.25}',
#              '{"id":109415,"plots_duration":"0h 26m '
#              '20s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":4418.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":280.0}',
#              '{"id":109498,"plots_duration":"0h 50m '
#              '52s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":6143.75,"plots_max_mach":0.816,"plots_max_measured_flight_level":390.0}',
#              '{"id":109588,"plots_duration":"0h 39m '
#              '9s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.768,"plots_max_measured_flight_level":360.0}',
#              '{"id":109683,"plots_duration":"1h 11m '
#              '30s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":8193.75,"plots_max_mach":0.776,"plots_max_measured_flight_level":400.0}',
#              '{"id":109686,"plots_duration":"0h 41m '
#              '49s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":193.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":371.0}',
#              '{"id":109704,"plots_duration":"0h 53m '
#              '19s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":481.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":370.0}',
#              '{"id":109825,"plots_duration":"0h 20m '
#              '7s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4162.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":367.0}',
#              '{"id":109837,"plots_duration":"0h 44m '
#              '26s","plots_max_baro_vert_rate":2400.0,"plots_max_mach":0.616,"plots_max_measured_flight_level":270.25}',
#              '{"id":109942,"plots_duration":"0h 36m '
#              '35s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":318.75,"plots_max_mach":0.856,"plots_max_measured_flight_level":340.0}',
#              '{"id":110060,"plots_duration":"0h 44m '
#              '19s","plots_max_altitude":43000.0,"plots_max_baro_vert_rate":4318.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.25}',
#              '{"id":110113,"plots_duration":"0h 39m '
#              '35s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4193.75,"plots_max_mach":0.816,"plots_max_measured_flight_level":380.25}',
#              '{"id":110125,"plots_duration":"0h 17m '
#              '16s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":2143.75,"plots_max_mach":0.728,"plots_max_measured_flight_level":350.0}',
#              '{"id":110254,"plots_duration":"0h 42m '
#              '3s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":5475.0,"plots_max_mach":0.76,"plots_max_measured_flight_level":360.0}',
#              '{"id":110298,"plots_duration":"0h 35m '
#              '33s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":361.0}',
#              '{"id":110317,"plots_duration":"0h 37m '
#              '47s","plots_max_altitude":25000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.584,"plots_max_measured_flight_level":250.0}',
#              '{"id":110415,"plots_duration":"0h 42m '
#              '26s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":1375.0,"plots_max_mach":0.472,"plots_max_measured_flight_level":170.0}',
#              '{"id":110504,"plots_duration":"0h 38m '
#              '34s","plots_max_altitude":24000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.584,"plots_max_measured_flight_level":240.0}',
#              '{"id":110561,"plots_duration":"0h 12m '
#              '20s","plots_max_altitude":10000.0,"plots_max_baro_vert_rate":2881.25,"plots_max_mach":0.448,"plots_max_measured_flight_level":82.0}',
#              '{"id":110574,"plots_duration":"0h 49m '
#              '6s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3518.75,"plots_max_mach":0.768,"plots_max_measured_flight_level":360.0}',
#              '{"id":110596,"plots_duration":"0h 5m '
#              '5s","plots_max_altitude":28000.0,"plots_max_baro_vert_rate":2625.0,"plots_max_mach":0.656,"plots_max_measured_flight_level":229.0}',
#              '{"id":110628,"plots_duration":"0h 45m '
#              '14s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4575.0,"plots_max_mach":0.776,"plots_max_measured_flight_level":350.0}',
#              '{"id":110660,"plots_duration":"0h 35m '
#              '37s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.88,"plots_max_measured_flight_level":380.0}',
#              '{"id":110738,"plots_duration":"0h 15m '
#              '53s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":575.0,"plots_max_mach":0.784,"plots_max_measured_flight_level":360.25}',
#              '{"id":110777,"plots_duration":"0h 17m '
#              '55s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":3362.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":350.0}',
#              '{"id":110873,"plots_duration":"0h 26m '
#              '57s","plots_max_measured_flight_level":190.0}',
#              '{"id":110884,"plots_duration":"0h 28m '
#              '55s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":4062.5,"plots_max_mach":0.776,"plots_max_measured_flight_level":360.0}',
#              '{"id":111040,"plots_duration":"0h 46m '
#              '34s","plots_max_altitude":24000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.576,"plots_max_measured_flight_level":240.25}',
#              '{"id":111051,"plots_duration":"0h 19m '
#              '0s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":62.5,"plots_max_mach":0.648,"plots_max_measured_flight_level":214.0}',
#              '{"id":111102,"plots_duration":"0h 30m '
#              '16s","plots_max_measured_flight_level":190.0}',
#              '{"id":111138,"plots_duration":"0h 35m '
#              '42s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.872,"plots_max_measured_flight_level":380.25}',
#              '{"id":111141,"plots_duration":"0h 27m '
#              '1s","plots_max_altitude":34000.0,"plots_max_baro_vert_rate":4675.0,"plots_max_mach":0.752,"plots_max_measured_flight_level":340.0}',
#              '{"id":111165,"plots_duration":"0h 36m '
#              '34s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.84,"plots_max_measured_flight_level":320.0}',
#              '{"id":111214,"plots_duration":"0h 38m '
#              '33s","plots_max_altitude":40000.0,"plots_max_baro_vert_rate":637.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":400.0}',
#              '{"id":111246,"plots_duration":"0h 29m '
#              '43s","plots_max_altitude":31000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.832,"plots_max_measured_flight_level":310.0}',
#              '{"id":111316,"plots_duration":"0h 25m '
#              '2s","plots_max_altitude":25000.0,"plots_max_baro_vert_rate":3006.25,"plots_max_mach":0.576,"plots_max_measured_flight_level":250.0}',
#              '{"id":111335,"plots_duration":"0h 40m '
#              '43s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":4481.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":111564,"plots_duration":"0h 22m '
#              '30s","plots_max_altitude":20000.0,"plots_max_baro_vert_rate":2781.25,"plots_max_mach":0.544,"plots_max_measured_flight_level":200.25}',
#              '{"id":111567,"plots_duration":"0h 22m '
#              '18s","plots_max_altitude":48825.0,"plots_max_baro_vert_rate":0.0,"plots_max_mach":0.504,"plots_max_measured_flight_level":187.5}',
#              '{"id":111651,"plots_duration":"0h 32m '
#              '33s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":330.0}',
#              '{"id":111657,"plots_duration":"0h 10m '
#              '36s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":2943.75,"plots_max_mach":0.576,"plots_max_measured_flight_level":209.25}',
#              '{"id":111671,"plots_duration":"0h 52m '
#              '26s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":4062.5,"plots_max_mach":0.768,"plots_max_measured_flight_level":370.0}',
#              '{"id":111706,"plots_duration":"0h 52m '
#              '46s","plots_max_altitude":15000.0,"plots_max_baro_vert_rate":2050.0,"plots_max_mach":0.488,"plots_max_measured_flight_level":150.25}',
#              '{"id":111735,"plots_duration":"0h 17m '
#              '15s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":31.25,"plots_max_mach":0.544,"plots_max_measured_flight_level":132.75}',
#              '{"id":111779,"plots_duration":"0h 55m '
#              '3s","plots_max_altitude":17000.0,"plots_max_baro_vert_rate":1693.75,"plots_max_mach":0.488,"plots_max_measured_flight_level":170.0}',
#              '{"id":111869,"plots_duration":"0h 25m '
#              '27s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":4543.75,"plots_max_mach":0.76,"plots_max_measured_flight_level":330.0}',
#              '{"id":111881,"plots_duration":"0h 7m '
#              '32s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":5218.75,"plots_max_mach":0.688,"plots_max_measured_flight_level":263.0}',
#              '{"id":111920,"plots_duration":"0h 46m '
#              '17s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":925.0,"plots_max_mach":0.8,"plots_max_measured_flight_level":390.0}',
#              '{"id":111982,"plots_duration":"0h 17m '
#              '14s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":418.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.25}',
#              '{"id":111987,"plots_duration":"0h 25m '
#              '0s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":2850.0,"plots_max_mach":0.84,"plots_max_measured_flight_level":330.0}',
#              '{"id":112010,"plots_duration":"0h 8m '
#              '20s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4162.5,"plots_max_mach":0.696,"plots_max_measured_flight_level":266.0}',
#              '{"id":112052,"plots_duration":"0h 18m '
#              '55s","plots_max_altitude":29000.0,"plots_max_baro_vert_rate":62.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":360.0}',
#              '{"id":112056,"plots_duration":"0h 8m '
#              '40s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":3168.75,"plots_max_mach":0.704,"plots_max_measured_flight_level":228.75}',
#              '{"id":112087,"plots_duration":"0h 24m '
#              '13s","plots_max_altitude":36000.0,"plots_max_baro_vert_rate":3075.0,"plots_max_mach":0.808,"plots_max_measured_flight_level":360.0}',
#              '{"id":112158,"plots_duration":"0h 43m '
#              '6s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":162.5,"plots_max_mach":0.76,"plots_max_measured_flight_level":370.0}',
#              '{"id":112162,"plots_duration":"0h 43m '
#              '32s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.776,"plots_max_measured_flight_level":380.0}',
#              '{"id":112163,"plots_duration":"0h 22m '
#              '9s","plots_max_altitude":22000.0,"plots_max_baro_vert_rate":2306.25,"plots_max_mach":0.536,"plots_max_measured_flight_level":220.0}',
#              '{"id":112181,"plots_duration":"0h 8m '
#              '9s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":4287.5,"plots_max_mach":0.704,"plots_max_measured_flight_level":283.0}',
#              '{"id":112400,"plots_duration":"0h 36m '
#              '32s","plots_max_altitude":41000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.864,"plots_max_measured_flight_level":410.0}',
#              '{"id":112492,"plots_duration":"0h 45m '
#              '44s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":543.75,"plots_max_mach":0.8,"plots_max_measured_flight_level":350.25}',
#              '{"id":112529,"plots_duration":"0h 31m '
#              '21s","plots_max_altitude":33000.0,"plots_max_baro_vert_rate":800.0,"plots_max_mach":0.832,"plots_max_measured_flight_level":330.0}',
#              '{"id":112531,"plots_duration":"1h 4m '
#              '56s","plots_max_altitude":16000.0,"plots_max_baro_vert_rate":350.0,"plots_max_mach":0.448,"plots_max_measured_flight_level":160.25}',
#              '{"id":112636,"plots_duration":"0h 46m '
#              '54s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":287.5,"plots_max_mach":0.792,"plots_max_measured_flight_level":380.0}',
#              '{"id":112672,"plots_duration":"0h 40m '
#              '52s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":1887.5,"plots_max_mach":0.808,"plots_max_measured_flight_level":350.0}',
#              '{"id":112731,"plots_duration":"0h 45m '
#              '45s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":1856.25,"plots_max_mach":0.76,"plots_max_measured_flight_level":350.0}',
#              '{"id":112783,"plots_duration":"0h 34m '
#              '41s","plots_max_altitude":37000.0,"plots_max_baro_vert_rate":93.75,"plots_max_mach":0.792,"plots_max_measured_flight_level":370.25}',
#              '{"id":112822,"plots_duration":"0h 23m '
#              '55s","plots_max_altitude":12000.0,"plots_max_baro_vert_rate":125.0,"plots_max_mach":0.592,"plots_max_measured_flight_level":241.25}',
#              '{"id":112953,"plots_duration":"0h 34m '
#              '28s","plots_max_altitude":13000.0,"plots_max_baro_vert_rate":1693.75,"plots_max_mach":0.456,"plots_max_measured_flight_level":130.0}',
#              '{"id":113050,"plots_duration":"0h 21m '
#              '37s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":450.0,"plots_max_mach":0.856,"plots_max_measured_flight_level":390.0}',
#              '{"id":113052,"plots_duration":"0h 34m '
#              '46s","plots_max_altitude":35000.0,"plots_max_baro_vert_rate":381.25,"plots_max_mach":0.856,"plots_max_measured_flight_level":350.0}',
#              '{"id":113071,"plots_duration":"0h 27m '
#              '16s","plots_max_altitude":38000.0,"plots_max_baro_vert_rate":256.25,"plots_max_mach":0.8,"plots_max_measured_flight_level":380.0}',
#              '{"id":113076,"plots_duration":"0h 31m '
#              '46s","plots_max_measured_flight_level":370.0}',
#              '{"id":113099,"plots_duration":"1h 0m '
#              '56s","plots_max_altitude":39000.0,"plots_max_baro_vert_rate":4193.75,"plots_max_mach":0.784,"plots_max_measured_flight_level":390.0}',
#              '{"id":113125,"plots_duration":"0h 19m '
#              '57s","plots_max_altitude":10000.0,"plots_max_baro_vert_rate":225.0,"plots_max_mach":0.656,"plots_max_measured_flight_level":195.25}',
#              '{"id":113145,"plots_duration":"0h 50m '
#              '2s","plots_max_measured_flight_level":131.0}',
#              '{"id":113158,"plots_duration":"0h 15m '
#              '5s","plots_max_altitude":32000.0,"plots_max_baro_vert_rate":3681.25,"plots_max_mach":0.656,"plots_max_measured_flight_level":213.0}'],
#  'unique_aircraft_type':
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
